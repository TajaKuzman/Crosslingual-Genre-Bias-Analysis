# %%
import gzip
import regex as re
import sys
import pandas as pd
import json

# %%
corpus_path = "datasets/sample.vert"

# %%
def vert_to_jsonl(corpus_path, gzip_file=True):
	"""
	Function to transform vertical format (vert) to jsonl format, based on the CLASSLA-web files. Change the function if the files contain other metadata.

	Args:
	- corpus_path: path to the dataset in VERT format
	- gzip_file: whether the file is gzipped. Defaults to true.
	"""
	if gzip_file == True:
		corpus = gzip.open(corpus_path, "rt")
	else:
		corpus = open(corpus_path, "r")

	# Open a new file to which we will append each json line
	new_file = open("{}.jsonl".format(corpus_path), "w")
	new_file.close()
	new_file = open("{}.jsonl".format(corpus_path), "a")

	text_id_re = re.compile('id="(.+?)"')
	url_re = re.compile('url="(.+?)"')
	domain_re = re.compile('domain="(.+?)"')
	genre_re = re.compile('genre="(.+?)"')

	text_counter = 0

	for line in corpus:
		if line.startswith("<text"):
			current_text = {}
			text_string = ""
			current_text["text_id"] = text_id_re.search(line).group(1)
			current_text["url"] = url_re.search(line).group(1)
			current_text["domain"] = domain_re.search(line).group(1)
			current_text["genre"] = genre_re.search(line).group(1)
			current_text["text"] = ""
			current_text["text_length"] = 0
			current_ling_anno = []
		elif line.startswith("<p"):
			continue
		elif line.startswith("<s"):
			continue
		elif line.startswith("</p"):
			text_string = text_string.rstrip()
			text_string += "\n"
		elif line.startswith("</s"):
			continue
		elif line.startswith("<g"):
			# Remove space before the last word if there is a symbol <g (= glue, meaning no space between words)
			text_string = text_string.rstrip()
		elif line.startswith("</text>"):
			current_text["ling_anno"] = current_ling_anno
			current_text["text"] = text_string
			current_text["text_length"] = len(text_string.split())
			new_file.write("{}".format(current_text))
			new_file.write("\n")
			text_counter += 1
			if text_counter%10 == 0:
				print("Processed {} files.".format(text_counter))
		else:
			current_line = line.split("\t")
			current_line_dict = {"word": current_line[0], "lemma": current_line[1], "xpos": current_line[2], "upos": current_line[3], "feats": current_line[4], "id": current_line[5].replace("\n", "")}
			current_ling_anno.append(current_line_dict)
			current_word = current_line[0]
			text_string += current_word
			text_string += " "
	
	new_file.close()
	print("Processing completed. The new file is saved as {}.jsonl".format(corpus_path))

# %%
def vert_to_txt_sample(corpus_path, gzip_file=True):
	"""
	Function to transform vertical format (vert) to jsonl format, based on the CLASSLA-web files.
	We will only extract a sample of 250 000 texts.

	Args:
	- corpus_path: path to the dataset in VERT format
	- gzip_file: whether the file is gzipped. Defaults to true.
	"""
	if gzip_file == True:
		corpus = gzip.open(corpus_path, "rt")
	else:
		corpus = open(corpus_path, "r")

	# Open a new file to which we will append each json line
	new_file = open("{}-sample.txt".format(corpus_path), "w")
	new_file.write("text_id\turl\tdomain\tgenre\ttext\ttext_length\n")
	new_file.close()
	new_file = open("{}-sample.txt".format(corpus_path), "a")

	text_id_re = re.compile('id="(.+?)"')
	url_re = re.compile('url="(.+?)"')
	domain_re = re.compile('domain="(.+?)"')
	genre_re = re.compile('genre="(.+?)"')

	text_counter = 0

	for line in corpus:
		if text_counter < 100000:
			if line.startswith("<text"):
				current_text = {}
				text_string = ""
				current_text["text_id"] = text_id_re.search(line).group(1)
				current_text["url"] = url_re.search(line).group(1)
				current_text["domain"] = domain_re.search(line).group(1)
				current_text["genre"] = genre_re.search(line).group(1)
				current_text["text"] = ""
				current_text["text_length"] = 0
			elif line.startswith("<p"):
				continue
			elif line.startswith("<s"):
				continue
			elif line.startswith("</p"):
				text_string = text_string.rstrip()
				text_string += "<p>"
			elif line.startswith("</s"):
				continue
			elif line.startswith("<g"):
				# Remove space before the last word if there is a symbol <g (= glue, meaning no space between words)
				text_string = text_string.rstrip()
			elif line.startswith("</text>"):
				current_text["text"] = text_string
				current_text["text_length"] = len(text_string.split())
				#new_file.write("{}".format(current_text))
				#new_file.write("\n")
				new_file.write("{}\t{}\t{}\t{}\t{}\t{}\n".format(current_text["text_id"],current_text["url"],current_text["domain"], current_text["genre"], current_text["text"], current_text["text_length"]))
				text_counter += 1
				if text_counter%10 == 0:
					print("Processed {} files.".format(text_counter))
			else:
				current_line = line.split("\t")
				current_word = current_line[0]
				text_string += current_word
				text_string += " "
		else:
			break
	
	new_file.close()
	print("Processing completed. The sample is saved as {}-sample.txt".format(corpus_path))

# %%
vert_to_txt_sample("datasets/CLASSLA-web.mk.1.0.vert.gz")

# %%
def extract_genre_sample(sample_path):
	df = pd.read_csv(sample_path, sep="\t")

	# We will extract all labels
	labels_list=['Other', 'Information/Explanation', 'News', 'Instruction', 'Opinion/Argumentation', 'Forum', 'Prose/Lyrical', 'Legal', 'Promotion']

	# Remove all texts, longer than 500 words
	df = df[df["text_length"] < 500]

	# First create the initial df to which all others in the loop will be added
	final_sample = df[df["genre"] == labels_list[0]].sample(n=10)

	# Add all other domains
	remaining_list = labels_list[1:]

	for i in remaining_list:
		try:
			added_instances = df[df["genre"] == i].sample(n=10)
			final_sample = pd.concat([final_sample, added_instances])
		except:
			print(df[df["genre"] == i][:2].to_markdown())

	# Shuffle rows
	final_sample = final_sample.sample(frac=1)

	# Save sample
	final_sample.to_csv("{}-genre-sample.txt".format(sample_path), sep="\t")
	
	return final_sample

# %%
mk_genre = extract_genre_sample("datasets/CLASSLA-web.mk.1.0.vert.gz-sample.txt")

mk_genre
# Out:
#                       text_id  \
# 15197    CLASSLA-web.mk.18600
# 46057   CLASSLA-web.mk.138126
# 38999   CLASSLA-web.mk.921342
# 48491   CLASSLA-web.mk.384653
# 99412  CLASSLA-web.mk.1050389
# ...                       ...
# 68027   CLASSLA-web.mk.874985
# 23267   CLASSLA-web.mk.828276
# 86580  CLASSLA-web.mk.1247279
# 62432   CLASSLA-web.mk.313556
# 77440   CLASSLA-web.mk.339298
#
#                                                      url  \
# 15197                          https://radar.mk/?p=29847
# 46057                  https://emiter.com.mk/napis/10922
# 38999  http://www.interesno.mk/nauka/38-nauka/50238-k...
# 48491  https://www.mn.mk/pesni-za-makedonija/6075-Dob...
# 99412  http://forum.carclub.mk/index.php/topic,102.ms...
# ...                                                  ...
# 68027  https://crithink.mk/zloupotrebata-na-naslovite...
# 23267  https://skopjeinfo.mk/sakate-da-ste-posrekjni-...
# 86580  http://proverkanafakti.mk/recenzija-brojot-na-...
# 62432       http://1000knigi.mon.gov.mk/book.php?id=1731
# 77440   https://vakataka.mk/shokantni-fakti-za-cigarite/
#
#                      domain                    genre  \
# 15197              radar.mk  Information/Explanation
# 46057         emiter.com.mk  Information/Explanation
# 38999          interesno.mk              Instruction
# 48491                 mn.mk            Prose/Lyrical
# 99412      forum.carclub.mk                    Forum
# ...                     ...                      ...
# 68027           crithink.mk                    Other
# 23267         skopjeinfo.mk              Instruction
# 86580    proverkanafakti.mk    Opinion/Argumentation
# 62432  1000knigi.mon.gov.mk  Information/Explanation
# 77440           vakataka.mk  Information/Explanation
#
#                                                     text  text_length
# 15197  Топењето на мразот е посебен феномен од 21-от ...          269
# 46057  Широката распространетост на РЕЛ-заварувањето ...          204
# 38999  Кои хороскопски знаци ќе ги погоди Розевата По...          195
# 48491  Валентина Ѓоргиевска Парго Добриот човек го им...          373
# 99412  Провери си тука http://www.autobulbsdirect.co....          440
# ...                                                  ...          ...
# 68027  Злоупотребата на насловите за повеќе кликови е...          471
# 23267  Сакате да сте посреќни? Намалете го хаосот во ...          444
# 86580  ФАЛБИ БЕЗ СРАМ!<p>Имено, овој исклучително нео...          329
# 62432  Сексуално преносливи болести<p>Автори:<p>978-6...          230
# 77440  Во димот од цигарата има околу 4,000 хемикалии...          152
#
# [90 rows x 6 columns]

# %%
mk_genre.describe(include="all")
# Out:
#                      text_id                        url            domain  \
# count                     90                         90                90
# unique                    90                         90                63
# top     CLASSLA-web.mk.18600  https://radar.mk/?p=29847  forum.carclub.mk
# freq                       1                          1                 5
# mean                     NaN                        NaN               NaN
# std                      NaN                        NaN               NaN
# min                      NaN                        NaN               NaN
# 25%                      NaN                        NaN               NaN
# 50%                      NaN                        NaN               NaN
# 75%                      NaN                        NaN               NaN
# max                      NaN                        NaN               NaN
#
#                           genre  \
# count                        90
# unique                        9
# top     Information/Explanation
# freq                         10
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN
#
#                                                      text  text_length
# count                                                  90    90.000000
# unique                                                 90          NaN
# top     Топењето на мразот е посебен феномен од 21-от ...          NaN
# freq                                                    1          NaN
# mean                                                  NaN   230.355556
# std                                                   NaN   113.578989
# min                                                   NaN    86.000000
# 25%                                                   NaN   134.500000
# 50%                                                   NaN   200.500000
# 75%                                                   NaN   311.750000
# max                                                   NaN   496.000000

# %%
hr_genre = extract_genre_sample("datasets/CLASSLA-web.hr.1.0.vert.gz-sample.txt")

hr_genre
# Out:
#                       text_id  \
# 97669  CLASSLA-web.hr.4346000
# 65197  CLASSLA-web.hr.1088566
# 56399   CLASSLA-web.hr.202668
# 38714  CLASSLA-web.hr.3837178
# 60756   CLASSLA-web.hr.643955
# ...                       ...
# 49283  CLASSLA-web.hr.4908191
# 30515  CLASSLA-web.hr.3031426
# 78461  CLASSLA-web.hr.2419400
# 24999  CLASSLA-web.hr.2486817
# 4589    CLASSLA-web.hr.450145
#
#                                                      url  \
# 97669       https://podravske-sirine.com.hr/arhiva/11701
# 65197   https://www.moj-film.hr/film/info/casino-royale/
# 56399  https://nogometplus.net/guingamp-vise-clanova-...
# 38714  https://hrvatska-danas.com/2021/08/26/splicani...
# 60756  https://www.ictbusiness.info/ictbusiness-tv/ic...
# ...                                                  ...
# 49283        https://teatarexit.hr/politike-privatnosti/
# 30515  https://www.pula.hr/hr/uprava/gradonacelnik/za...
# 78461  https://www.zooplus.hr/shop/psi/hrana_za_pse_s...
# 24999  https://www.cromoda.com/nose-se-cizme-i-tobice...
# 4589   https://www.klubskascena.hr/aktualno/fokus/18-...
#
#                         domain                    genre  \
# 97669  podravske-sirine.com.hr  Information/Explanation
# 65197              moj-film.hr                    Other
# 56399          nogometplus.net    Opinion/Argumentation
# 38714       hrvatska-danas.com                     News
# 60756         ictbusiness.info                     News
# ...                        ...                      ...
# 49283            teatarexit.hr                    Legal
# 30515                  pula.hr                    Legal
# 78461               zooplus.hr                Promotion
# 24999              cromoda.com                    Other
# 4589           klubskascena.hr                    Other
#
#                                                     text  text_length
# 97669  Batine kao mjera kažnjavanja u Vojnoj krajini<...          202
# 65197  Sinopsis<p>CASINO ROYALE predstavlja JAMESA BO...          121
# 56399  Guingamp: Više članova nego stanovnika<p>Prije...          111
# 38714  Splićanin na radu u Wuhanu: U tri dana testira...           94
# 60756  ICTbusiness TV: Brza i efikasna softverska rje...          133
# ...                                                  ...          ...
# 49283  Politike privatnosti<p>Online prodaja karata o...          194
# 30515  Zamjenici gradonačelnika<p>Gradonačelnik ima j...          116
# 78461  Happy Dog Supreme Young Junior Original<p>294....          254
# 24999  Nose se čizme i tobice u kaubojskom stilu: Evo...          100
# 4589   Otvorili smo arhivu fotografija s partija od 1...          162
#
# [90 rows x 6 columns]

# %%
hr_genre.describe(include="all")
# Out:
#                        text_id                                           url  \
# count                       90                                            90
# unique                      90                                            90
# top     CLASSLA-web.hr.4346000  https://podravske-sirine.com.hr/arhiva/11701
# freq                         1                                             1
# mean                       NaN                                           NaN
# std                        NaN                                           NaN
# min                        NaN                                           NaN
# 25%                        NaN                                           NaN
# 50%                        NaN                                           NaN
# 75%                        NaN                                           NaN
# max                        NaN                                           NaN
#
#                  domain                    genre  \
# count                90                       90
# unique               84                        9
# top     metro-portal.hr  Information/Explanation
# freq                  3                       10
# mean                NaN                      NaN
# std                 NaN                      NaN
# min                 NaN                      NaN
# 25%                 NaN                      NaN
# 50%                 NaN                      NaN
# 75%                 NaN                      NaN
# max                 NaN                      NaN
#
#                                                      text  text_length
# count                                                  90    90.000000
# unique                                                 90          NaN
# top     Batine kao mjera kažnjavanja u Vojnoj krajini<...          NaN
# freq                                                    1          NaN
# mean                                                  NaN   204.955556
# std                                                   NaN   116.402818
# min                                                   NaN    74.000000
# 25%                                                   NaN   118.000000
# 50%                                                   NaN   171.500000
# 75%                                                   NaN   258.750000
# max                                                   NaN   491.000000

# %%
sl_genre = extract_genre_sample("datasets/CLASSLA-web.sl.1.0.vert.gz-sample.txt")

sl_genre
# Out:
#                       text_id  \
# 47895   CLASSLA-web.sl.693122
# 64374  CLASSLA-web.sl.2342984
# 84107   CLASSLA-web.sl.269562
# 28638  CLASSLA-web.sl.2846516
# 94595  CLASSLA-web.sl.1320205
# ...                       ...
# 35571  CLASSLA-web.sl.3521045
# 45195   CLASSLA-web.sl.420198
# 39905  CLASSLA-web.sl.3956557
# 69750  CLASSLA-web.sl.2886985
# 21544  CLASSLA-web.sl.2133726
#
#                                                      url  \
# 47895  https://www.sloski.si/index.php?t=news&amp;amp...
# 64374  http://duhresnice.blog.siol.net/2015/07/26/mli...
# 84107  https://www.vzmd.si/novice/mediji-o-malih-deln...
# 28638               https://www.drugisvet.com/tag/drzava
# 94595  https://www.sodisce.si/znanje/sodna_praksa/vis...
# ...                                                  ...
# 35571  http://bos.zrc-sazu.si/c/neva.exe?n=a_si_s&amp...
# 45195  https://www.tekac.si/novica/5-razteznih-vaj-za...
# 39905  https://www.igrace-populi.com/izdelek/kuharski...
# 69750  https://www.ecco-verde.si/erbe-de-janas/indigo...
# 21544  http://forum.kvarkadabra.net/viewtopic.php?f=2...
#
#                          domain                  genre  \
# 47895                 sloski.si                   News
# 64374  duhresnice.blog.siol.net          Prose/Lyrical
# 84107                   vzmd.si                  Other
# 28638             drugisvet.com  Opinion/Argumentation
# 94595                sodisce.si                  Legal
# ...                         ...                    ...
# 35571           bos.zrc-sazu.si          Prose/Lyrical
# 45195                  tekac.si            Instruction
# 39905         igrace-populi.com              Promotion
# 69750             ecco-verde.si            Instruction
# 21544     forum.kvarkadabra.net                  Forum
#
#                                                     text  text_length
# 47895  Nordijska kombinacija<p>Mladi kombinatorci so ...          454
# 64374  Strani<p>Jul<p>26<p>V vertikali je neskončna m...          245
# 84107  RA SLOVENIJA 1, 02.08.2012, DRUGA JUTRANJA KRO...          291
# 28638  V tej državi se ne znamo lotevati problemov. R...           77
# 94595  JEDRO: Verjetnost obstoja terjatve se presoja ...          425
# ...                                                  ...          ...
# 35571  Mi, kar nas je velikih, smo bili tako zamaknje...           93
# 45195  5 razteznih vaj za tekače<p>Poglejte kako se u...          358
# 39905  Ta obsežen set za peko bo vsakega mladega kuha...           75
# 69750  Opis<p>Indigo v prahu je prijeten naraven izde...          146
# 21544  Zdravo, prosila bi za pomoč pri nalogi iz niha...          108
#
# [90 rows x 6 columns]

# %%
sl_genre.describe(include="all")
# Out:
#                       text_id  \
# count                      90
# unique                     90
# top     CLASSLA-web.sl.693122
# freq                        1
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN
#
#                                                       url       domain genre  \
# count                                                  90           90    90
# unique                                                 90           79     9
# top     https://www.sloski.si/index.php?t=news&amp;amp...  besedilo.si  News
# freq                                                    1            5    10
# mean                                                  NaN          NaN   NaN
# std                                                   NaN          NaN   NaN
# min                                                   NaN          NaN   NaN
# 25%                                                   NaN          NaN   NaN
# 50%                                                   NaN          NaN   NaN
# 75%                                                   NaN          NaN   NaN
# max                                                   NaN          NaN   NaN
#
#                                                      text  text_length
# count                                                  90    90.000000
# unique                                                 90          NaN
# top     Nordijska kombinacija<p>Mladi kombinatorci so ...          NaN
# freq                                                    1          NaN
# mean                                                  NaN   203.844444
# std                                                   NaN   121.000038
# min                                                   NaN    64.000000
# 25%                                                   NaN   108.500000
# 50%                                                   NaN   156.000000
# 75%                                                   NaN   267.250000
# max                                                   NaN   486.000000

# %%
sl_genre[sl_genre["domain"] == "besedilo.si"]
# Out:
#                       text_id  \
# 96495  CLASSLA-web.sl.1507108
# 55640  CLASSLA-web.sl.1463952
# 56091  CLASSLA-web.sl.1506939
# 96377  CLASSLA-web.sl.1494196
# 55741  CLASSLA-web.sl.1475509
#
#                                                      url       domain  \
# 96495  https://www.besedilo.si/aleksander-jez/vroce-j...  besedilo.si
# 55640      https://www.besedilo.si/werner/ti-ljubezen-si  besedilo.si
# 56091  https://www.besedilo.si/ansambel-kvinta/nisem-...  besedilo.si
# 96377  https://www.besedilo.si/ansambel-borst/kdor-je...  besedilo.si
# 55741  https://www.besedilo.si/ansambel-petra-finka/r...  besedilo.si
#
#                genre                                               text  \
# 96495  Prose/Lyrical  Vroče je, ti pa si hladna<p>Zunaj vroče je in ...
# 55640  Prose/Lyrical  Ti ljubezen si<p>Izvajalec: Werner Izvajalec: ...
# 56091  Prose/Lyrical  Nisem taka kot so druge<p>Nočem rož, ne bombon...
# 96377  Prose/Lyrical  Kdor je v srcu mlad<p>Svet vrti se vedno v ist...
# 55741  Prose/Lyrical  Ribič<p>Nad mestom se dan budi, galebi kričijo...
#
#        text_length
# 96495           64
# 55640          110
# 56091          150
# 96377           86
# 55741           91
