# %% [markdown]
# In this notebook, we are working with files that we created by automatically annotating MaCoCu corpora - they are in TSV or JSON format.

# %%
# Define the gpu  on the gpu machine
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=0

# %%
import pandas as pd
from tqdm import tqdm
import gzip
import regex as re
import sys
import pandas as pd
import json
from tqdm import tqdm

# %% [markdown]
# ## Analyze the file, created with automatic genre identification

# %%
suffix = "uk-1.0"
path = f"/cache/tajak/macocu-mt/datasets/annotated/MaCoCu-{suffix}.tsv-genre-annotated.jsonl"
lang = "uk"

# Open tsv (created by above process) or json (created with the python_extended.py script)

if ".tsv" in path[-6:]:
    df = pd.read_csv(path, sep="\t", index_col = 0)
elif ".json" in path[-6:]:
    df = pd.read_json(path, orient="records", lines=True)

display(df)
# Out:
#                  document_id  \
# 0                macocu.uk.1
# 1                macocu.uk.2
# 2                macocu.uk.3
# 3                macocu.uk.4
# 4                macocu.uk.5
# ...                      ...
# 13465417  macocu.uk.21471609
# 13465418  macocu.uk.21471610
# 13465419  macocu.uk.21471611
# 13465420  macocu.uk.21471612
# 13465421  macocu.uk.21471613
#
#                                                        text  \
# 0         1. Хлюпотить стрімка водичка, В’ється, ллється...
# 1         Лопух угору звівши вуха, Уранці Півня пісню сл...
# 2         *** Я кохала Тебе норовливо червнево-серпнево....
# 3         Інформація про роботу <p>Міністерство освіти і...
# 4         Інформація про роботу <p>Контрольна робота із ...
# ...                                                     ...
# 13465417  протоієрей Павло МЕЛЬНИК, Духовність як відхід...
# 13465418  А. Л. Дудніков, доцент кафедри криміналістики ...
# 13465419  Ключові слова: управління персоналом органів в...
# 13465420  Ж.В. ЗАВАЛЬНА, докт. юрид. наук, доц., Сумська...
# 13465421  О. І. МИКОЛЕНКО, докт. юрид. наук, доц., Одесь...
#
#                             genre  \
# 0                   Prose/Lyrical
# 1                   Prose/Lyrical
# 2                           Forum
# 3         Information/Explanation
# 4         Information/Explanation
# ...                           ...
# 13465417  Information/Explanation
# 13465418  Information/Explanation
# 13465419  Information/Explanation
# 13465420  Information/Explanation
# 13465421  Information/Explanation
#
#                                                       logit
# 0         [-0.46740186214447005, -1.549988031387329, -0....
# 1         [-0.325899422168731, -1.684817552566528, -0.97...
# 2         [1.543481707572937, -1.662479043006897, -2.043...
# 3         [-0.656804740428924, 8.27550983428955, -0.6994...
# 4         [-0.7865087389945981, 8.310611724853516, -0.67...
# ...                                                     ...
# 13465417  [-0.25334486365318304, 7.606439113616943, -0.9...
# 13465418  [-0.7717455029487611, 8.313455581665039, -0.78...
# 13465419  [-0.9155022501945491, 8.2792329788208, -0.6855...
# 13465420  [-0.809449970722198, 8.302559852600098, -0.776...
# 13465421  [-0.7954551577568051, 8.254680633544922, -0.95...
#
# [13465422 rows x 4 columns]

# %%
print(df.genre.value_counts(normalize="True").to_markdown())
print("\n\n")
print(df.genre.value_counts().to_markdown())
# Out:
# | genre                   |   proportion |
# |:------------------------|-------------:|
# | News                    |   0.61676    |
# | Opinion/Argumentation   |   0.0735929  |
# | Promotion               |   0.0685441  |
# | Information/Explanation |   0.0673885  |
# | Instruction             |   0.0658549  |
# | Forum                   |   0.0487328  |
# | Mix                     |   0.0331768  |
# | Other                   |   0.0115414  |
# | Legal                   |   0.00858311 |
# | Prose/Lyrical           |   0.00582556 |
#
#
#
# | genre                   |   count |
# |:------------------------|--------:|
# | News                    |  893978 |
# | Opinion/Argumentation   |  106671 |
# | Promotion               |   99353 |
# | Information/Explanation |   97678 |
# | Instruction             |   95455 |
# | Forum                   |   70637 |
# | Mix                     |   48089 |
# | Other                   |   16729 |
# | Legal                   |   12441 |
# | Prose/Lyrical           |    8444 |

# %%
df.genre.describe()
# Out:
# count     3990599
# unique         10
# top          News
# freq      1747488
# Name: genre, dtype: object

# %% [markdown]
# ## Create a genre sample

# %% [markdown]
# For the sample, we will take random 10 instances from each of the categories, except Other and Mix.

# %%
def extract_genre_sample(df, source_lang):
	import googletrans
	from googletrans import Translator

	# We will extract all labels, except Mix and Other
	labels_list=['Information/Explanation', 'News', 'Instruction', 'Opinion/Argumentation', 'Forum', 'Prose/Lyrical', 'Legal', 'Promotion']

	# First create the initial df to which all others in the loop will be added
	final_sample = df[df["genre"] == labels_list[0]].sample(n=10)

	# Add all other domains
	remaining_list = labels_list[1:]

	for i in remaining_list:
		try:
			added_instances = df[df["genre"] == i].sample(n=10)
			final_sample = pd.concat([final_sample, added_instances])
		except:
			print(df[df["genre"] == i][:2].to_markdown())

	# Shuffle rows
	final_sample = final_sample.sample(frac=1)

	# Discard logit information
	final_sample = final_sample.drop(columns="logit")

	# Change <p> signs to actual new lines
	final_sample["text"] = final_sample["text"].str.replace("<p>", "\n\n")

	sentence_list = final_sample["text"].to_list()

	# Apply Google Translate and machine translate the data - documentation: https://py-googletrans.readthedocs.io/en/latest/

	# Define the translation model
	translator = Translator()

	# Create the final list
	translation_GT = []

	print("Starting translation.")

	# The suffix that GT uses for all languages is the same as the suffix used in the dataset names, except for Montenegrin
	# GT does not have a special model for Montenegrin, so we will use the Serbian model
	if source_lang == "cnr":
		lang = "sr"
	else:
		lang = source_lang

	# Loop through the list of original sentences,
	# translate each and append the translation to the final list
	for i in sentence_list:
		# Translate the sentence from source language, e.g. Slovene (src = "sl") to English (dest = "en")
			current_translation = translator.translate(i, src = lang, dest='en')
		# Append the translated sentence to the final list
			translation_GT.append(current_translation.text)

	print("Translation finished.")

	# Append translations to the sample

	final_sample["translation"] = translation_GT

	# Save to JSON lines
	final_sample.to_json("/cache/tajak/macocu-mt/datasets/samples/MaCoCu-{}-genre-sample.json".format(source_lang), orient="records", lines=True)

	print("Final file saved as MaCoCu-{}-genre-sample.json".format(source_lang))

	# Create also a version for the annotation tool, only with translation and labels
	ann_df = final_sample[["translation","genre"]]

	# For annotation, each label should be in a list
	ann_df["genre"] = ann_df["genre"].apply(lambda x:[x])

	# Rename df
	ann_df.columns = ["text", "label"]

	# Add metadata
	text_ids = final_sample["document_id"].to_list()
	#domains = final_sample["domain"].to_list()

	metadata_list = []

	for i in list(zip(text_ids)):#,domains)):
		metadata = {"text_id": i[0]}#, "domain": i[1]}
		metadata_list.append(metadata)

	ann_df["metadata"] = metadata_list

	# Save to JSON lines
	ann_df.to_json("/cache/tajak/macocu-mt/datasets/samples/MaCoCu-{}-genre-sample-for-annotation-tool.json".format(source_lang), orient="records", lines=True)

	print("File for annotation saved as MaCoCu-{}-genre-sample-for-annotation-tool.json".format(source_lang))
	
	return final_sample

# %%
sample = extract_genre_sample(df, lang)
# Out:
# Starting translation.
# Translation finished.
# Final file saved as MaCoCu-uk-genre-sample.json
# File for annotation saved as MaCoCu-uk-genre-sample-for-annotation-tool.json
# /tmp/ipykernel_3395917/2498906653.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ann_df["genre"] = ann_df["genre"].apply(lambda x:[x])
# /tmp/ipykernel_3395917/2498906653.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ann_df["metadata"] = metadata_list

# %%
genre_file = pd.read_json(f"/cache/tajak/macocu-mt/datasets/samples/MaCoCu-{lang}-genre-sample-for-annotation-tool.json", orient="records", lines=True)

display(genre_file.head())
# Out:
#                                                 text  \
# 0  AÖL warned of frequent negligence and errors o...
# 1  Criteria to be applied in the tender for bank ...
# 2  all\n\nFriday, March 22, 2019, the Qur'an and ...
# 3  ----------------------------------------------...
# 4  Sender Subject: First Step to Beekeeping (Read...
#
#                        label                           metadata
# 0              [Instruction]  {'text_id': 'macocu.tr.15851513'}
# 1                    [Legal]  {'text_id': 'macocu.tr.12699738'}
# 2  [Information/Explanation]    {'text_id': 'macocu.tr.833490'}
# 3    [Opinion/Argumentation]   {'text_id': 'macocu.tr.9263252'}
# 4                    [Forum]  {'text_id': 'macocu.tr.12349626'}

# %%
genre_file.label.value_counts()
# Out:
# label
# [Instruction]                10
# [Legal]                      10
# [Information/Explanation]    10
# [Opinion/Argumentation]      10
# [Forum]                      10
# [News]                       10
# [Prose/Lyrical]              10
# [Promotion]                  10
# Name: count, dtype: int64

# %%
genre_file.shape
# Out:
# (1303402, 2)

# %% [markdown]
# ## Add additional instances to the sample to achieve 10 instances per label

# %%
# Open the entire corpus, annotated with genres

#suffix = "uk-1.0"
#path = f"/cache/tajak/macocu-mt/datasets/annotated/MaCoCu-{suffix}.tsv-genre-annotated.jsonl"
#path = f"datasets/annotated/MaCoCu-sq-texts-with-genres.tsv"
path = "datasets/annotated/CLASSLA-web-sl-genre-annotated.jsonl"
#lang = suffix[:2]
lang = "sl"
source_lang = lang

# Open tsv (created by above process) or json (created with the python_extended.py script)

if ".tsv" in path[-6:]:
    df = pd.read_csv(path, sep="\t", index_col = 0)
elif ".json" in path[-6:]:
    df = pd.read_json(path, orient="records", lines=True)

display(df)
# Out:
#                     document_id                    genre  \
# 0             CLASSLA-web.sl.36                Promotion
# 1            CLASSLA-web.sl.181  Information/Explanation
# 2            CLASSLA-web.sl.203              Instruction
# 3            CLASSLA-web.sl.259  Information/Explanation
# 4            CLASSLA-web.sl.335              Instruction
# ...                         ...                      ...
# 3958835  CLASSLA-web.sl.4062607  Information/Explanation
# 3958836  CLASSLA-web.sl.4062894                Promotion
# 3958837  CLASSLA-web.sl.4063133                Promotion
# 3958838  CLASSLA-web.sl.4063346                Promotion
# 3958839  CLASSLA-web.sl.4063403    Opinion/Argumentation
#
#                                                       text
# 0        Nakit /<p>Študij smeri NAKIT bo študentom nudi...
# 1        Modna krila<p>Krila so oblačila, ki so namenje...
# 2        Električna kitara – dobro je vedeti<p>Električ...
# 3        Nacionalni inštitut za biologijo Oddelek za bi...
# 4        Kako opremiti hodnik v stanovanju?<p>Hodnik la...
# ...                                                    ...
# 3958835  Uporaba: Za Land Rover Range Rover III SUV (LM...
# 3958836  Pošlji prijatelju<p>100Sets 8 mm Multicolor St...
# 3958837  Prednosti v primerjavi s HID & Halogenske žarn...
# 3958838  2020 Novih Moških Svile, Svileni Mreži majice ...
# 3958839  Pastirski dan na Vačah<p>V sredo, 18. 6. 2014,...
#
# [3958840 rows x 3 columns]

# %% [markdown]
# Open the manually-annotated sample as well

# %%
# In case of first run of adding instances
#ann_df = pd.read_json(f"datasets/manually-evaluated/MaCoCu-{lang}-genre-sample-evaluated.jsonl", lines=True)

# In case of second run of adding instances
ann_df = pd.read_json(f"datasets/manually-evaluated/MaCoCu-{lang}-genre-sample-evaluated-complete-sample.jsonl", lines=True)

ann_df.describe(include="all")
# Out:
#                        text_id y_pred  \
# count                       96     96
# unique                      96      9
# top     CLASSLA-web.sl.1022390   News
# freq                         1     12
#
#                                                      text  \
# count                                                  96
# unique                                                 96
# top     Znova je čas za poletne bralne podvige – poziv...
# freq                                                    1
#
#                                               translation  \
# count                                                  96
# unique                                                 96
# top     It is time for summer reading feats - we urge ...
# freq                                                    1
#
#                                                 metadata     y_true
# count                                                 96         96
# unique                                                96         10
# top     CLASSLA-web.sl.1022390', 'domain': 'log.sik.si'}  Promotion
# freq                                                   1         13

# %%
# Filter out "Other" instances and "Problematic" instances so that we will do analysis on clear examples only
df_test_clean = ann_df[ann_df["y_pred"] != "Other"]
df_test_clean = df_test_clean[df_test_clean["y_true"] != "Multiple texts"]
df_test_clean = df_test_clean[df_test_clean["y_true"] != "Incomprehensible"]
df_test_clean = df_test_clean[df_test_clean["y_true"] != "Other"]

label_count_dict = df_test_clean["y_pred"].value_counts().to_dict()
label_count_dict
# Out:
# {'Opinion/Argumentation': 10,
#  'Instruction': 10,
#  'Promotion': 10,
#  'Legal': 10,
#  'Information/Explanation': 10,
#  'Prose/Lyrical': 10,
#  'Forum': 10,
#  'News': 9}

# %%
# Calculate how many texts are missing
label_missing_count = {}

for item in list(label_count_dict.items()):
	if item[1] != 10:
		label_missing_count[item[0]] = int(10-item[1])

label_missing_count
# Out:
# {'News': 1}

# %%
# Get information about text ids so that we won't extract the same id
text_ids = df_test_clean["text_id"].to_list()
text_ids[:3]
# Out:
# ['CLASSLA-web.sl.1087171', 'CLASSLA-web.sl.1215246', 'CLASSLA-web.sl.1230602']

# %% [markdown]
# For each label, take additional instances, if the num of instances is less than 10. Make sure that the text id is different than those that are in the df.

# %%
# We will extract all labels that are missing, except Mix and Other
labels_list = list(label_missing_count.keys())

# First create the initial df to which all others in the loop will be added
final_sample = df[df["genre"] == labels_list[0]].sample(n=label_missing_count[labels_list[0]])

# Add all other domains
remaining_list = labels_list[1:]

for i in remaining_list:
	try:
		added_instances = df[df["genre"] == i].sample(n=label_missing_count[i])
		final_sample = pd.concat([final_sample, added_instances])
	except:
		print(df[df["genre"] == i][:2].to_markdown())

# Check whether any of the text ids are duplicated
new_text_ids = final_sample["document_id"].to_list()
# Modification to the code for sq
#new_text_ids = final_sample["text_id"].to_list()

combined_list = new_text_ids + text_ids
if len(combined_list) == len(set(combined_list)):
	print("No duplicated texts.")
else:
	print("There are duplicated texts, repeat the process.")

# Shuffle rows
final_sample = final_sample.sample(frac=1)

# Discard logit information
#final_sample = final_sample.drop(columns="logit")

# Change <p> signs to actual new lines
final_sample["text"] = final_sample["text"].str.replace("<p>", "\n\n")

sentence_list = final_sample["text"].to_list()

final_sample
# Out:
# No duplicated texts.
#                   document_id genre  \
# 564682  CLASSLA-web.sl.907174  News
#
#                                                      text
# 564682  Tunel pod središčem Maribora? Prva poročila so...

# %%
def extract_additional_genre_sample(sentence_list, source_lang, final_sample):
	import googletrans
	from googletrans import Translator

	# Apply Google Translate and machine translate the data - documentation: https://py-googletrans.readthedocs.io/en/latest/

	# Define the translation model
	translator = Translator()

	# Create the final list
	translation_GT = []

	print("Starting translation.")

	# The suffix that GT uses for all languages is the same as the suffix used in the dataset names, except for Montenegrin
	# GT does not have a special model for Montenegrin, so we will use the Serbian model
	if source_lang == "cnr":
		lang = "sr"
	else:
		lang = source_lang

	# Loop through the list of original sentences,
	# translate each and append the translation to the final list
	for i in sentence_list:
		# Translate the sentence from source language, e.g. Slovene (src = "sl") to English (dest = "en")
			current_translation = translator.translate(i, src = lang, dest='en')
		# Append the translated sentence to the final list
			translation_GT.append(current_translation.text)

	print("Translation finished.")

	# Append translations to the sample

	final_sample["translation"] = translation_GT

	# Save to JSON lines

	# In case of first run
	#final_sample.to_json("/cache/tajak/macocu-mt/datasets/samples/MaCoCu-{}-genre-sample-additional-instances.json".format(source_lang), orient="records", lines=True)

	#print("Final file saved as MaCoCu-{}-genre-sample-additional-instances.json".format(source_lang))

	# In case of second run
	final_sample.to_json("/cache/tajak/macocu-mt/datasets/samples/MaCoCu-{}-genre-sample-additional-instances-run2.json".format(source_lang), orient="records", lines=True)

	print("Final file saved as MaCoCu-{}-genre-sample-additional-instances-run2.json".format(source_lang))

	# Create also a version for the annotation tool, only with translation and labels
	ann_df = final_sample[["translation","genre"]]

	# For annotation, each label should be in a list
	ann_df["genre"] = ann_df["genre"].apply(lambda x:[x])

	# Rename df
	ann_df.columns = ["text", "label"]

	# Add metadata
	text_ids = final_sample["document_id"].to_list()
	#text_ids = final_sample["text_id"].to_list()
	#domains = final_sample["domain"].to_list()

	metadata_list = []

	for i in list(zip(text_ids)):#,domains)):
		metadata = {"text_id": i[0]}#, "domain": i[1]}
		metadata_list.append(metadata)

	ann_df["metadata"] = metadata_list

	# Save to JSON lines
	# In case of first run
	#ann_df.to_json("/cache/tajak/macocu-mt/datasets/samples/MaCoCu-{}-genre-sample-for-annotation-tool-additional-instances.json".format(source_lang), orient="records", lines=True)

	# In case of second run of adding instances
	ann_df.to_json("/cache/tajak/macocu-mt/datasets/samples/MaCoCu-{}-genre-sample-for-annotation-tool-additional-instances-run2.json".format(source_lang), orient="records", lines=True)

	print("File for annotation saved as MaCoCu-{}-genre-sample-for-annotation-tool-additional-instances-run2.json".format(source_lang))
	
	return final_sample

# %%
sample = extract_additional_genre_sample(sentence_list, source_lang, final_sample)
# Out:
# Starting translation.
# Translation finished.
# Final file saved as MaCoCu-sl-genre-sample-additional-instances-run2.json
# File for annotation saved as MaCoCu-sl-genre-sample-for-annotation-tool-additional-instances-run2.json
# /tmp/ipykernel_1716875/1743442657.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ann_df["genre"] = ann_df["genre"].apply(lambda x:[x])
# /tmp/ipykernel_1716875/1743442657.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ann_df["metadata"] = metadata_list

# %%
genre_file = pd.read_json(f"/cache/tajak/macocu-mt/datasets/samples/MaCoCu-{lang}-genre-sample-for-annotation-tool-additional-instances-run2.json", orient="records", lines=True)

display(genre_file.head())
# Out:
#                                                 text   label  \
# 0  Tunnel below the center of Maribor?The first r...  [News]
#
#                                metadata
# 0  {'text_id': 'CLASSLA-web.sl.907174'}

# %%
genre_file.label.value_counts()
# Out:
# label
# [Prose/Lyrical]    1
# Name: count, dtype: int64

# %% [markdown]
# # Prepare similar JSONL corpora from CLASSLA corpora

# %% [markdown]
# This is needed so that we can extract additional instances easily.

# %%
lang = "hr"
corpus_path = f"/cache/tajak/macocu-mt/datasets/initial/CLASSLA-web.{lang}.1.0.vert.gz"

if ".gz" in corpus_path:
	corpus = gzip.open(corpus_path, "rt")
else:
	corpus = open(corpus_path, "r")

# %%
# Open a new file to which we will append each json line
new_path = f"/cache/tajak/macocu-mt/datasets/annotated/CLASSLA-web-{lang}-genre-annotated.jsonl"
new_file = open(f"{new_path}", "wt")
#new_file.close()
#new_file = open("{}".format(new_path), "a")

text_id_re = re.compile('id="(.+?)"')
genre_re = re.compile('genre="(.+?)"')

text_counter = 0

# %%
for line in corpus:
	if line.startswith("<text"):
		current_text = {}
		text_string = ""
		current_text["document_id"] = text_id_re.search(line).group(1)
		current_text["genre"] = genre_re.search(line).group(1)
		current_text["text"] = ""
		current_length = 0
	elif line.startswith("<p"):
		continue
	elif line.startswith("<s"):
		continue
	elif line.startswith("</p"):
		text_string = text_string.rstrip()
		text_string += "<p>"
	elif line.startswith("</s"):
		continue
	elif line.startswith("<g"):
		# Remove space before the last word if there is a symbol <g (= glue, meaning no space between words)
		text_string = text_string.rstrip()
	elif line.startswith("</text>"):
		# Shorten the texts to first 512 tokens
		space_re=re.compile(r'\s+',re.UNICODE)
		text = ' '.join(space_re.sub(' ',text_string).split(' ')[:512])
		current_text["text"] = text
		current_length = len(text.split())
		if current_length > 75:
			#new_file.write("{}".format(current_text))
			#new_file.write("\n")
			new_file.write(json.dumps(current_text)+'\n')
			new_file.flush()
		text_counter += 1
		if text_counter%10 == 0:
			print("Processed {} files.".format(text_counter))
	else:
		current_line = line.split("\t")
		current_word = current_line[0]
		text_string += current_word
		text_string += " "

new_file.close()
print("Processing completed. The new file is saved as {}.jsonl".format(corpus_path))
# Out:
# Processed 10 files.
# Processed 20 files.
# Processed 30 files.
# Processed 40 files.
# Processed 50 files.
# Processed 60 files.
# Processed 70 files.
# Processed 80 files.
# Processed 90 files.
# Processed 100 files.
# Processed 110 files.
# Processed 120 files.
# Processed 130 files.
# Processed 140 files.
# Processed 150 files.
# Processed 160 files.
# Processed 170 files.
# Processed 180 files.
# Processed 190 files.
# Processed 200 files.
# Processed 210 files.
# Processed 220 files.
# Processed 230 files.
# Processed 240 files.
# Processed 250 files.
# Processed 260 files.
# Processed 270 files.
# Processed 280 files.
# Processed 290 files.
# Processed 300 files.
# Processed 310 files.
# Processed 320 files.
# Processed 330 files.
# Processed 340 files.
# Processed 350 files.
# Processed 360 files.
# Processed 370 files.
# Processed 380 files.
# Processed 390 files.
# Processed 400 files.
# Processed 410 files.
# Processed 420 files.
# Processed 430 files.
# Processed 440 files.
# Processed 450 files.
# Processed 460 files.
# Processed 470 files.
# Processed 480 files.
# Processed 490 files.
# Processed 500 files.
# Processed 510 files.
# Processed 520 files.
# Processed 530 files.
# Processed 540 files.
# Processed 550 files.
# Processed 560 files.
# Processed 570 files.
# Processed 580 files.
# Processed 590 files.
# Processed 600 files.
# Processed 610 files.
# Processed 620 files.
# Processed 630 files.
# Processed 640 files.
# Processed 650 files.
# Processed 660 files.
# Processed 670 files.
# Processed 680 files.
# Processed 690 files.
# Processed 700 files.
# Processed 710 files.
# Processed 720 files.
# Processed 730 files.
# Processed 740 files.
# Processed 750 files.
# Processed 760 files.
# Processed 770 files.
# Processed 780 files.
# Processed 790 files.
# Processed 800 files.
# Processed 810 files.
# Processed 820 files.
# Processed 830 files.
# Processed 840 files.
# Processed 850 files.
# Processed 860 files.
# Processed 870 files.
# Processed 880 files.
# Processed 890 files.
# Processed 900 files.
# Processed 910 files.
# Processed 920 files.
# Processed 930 files.
# Processed 940 files.
# Processed 950 files.
# Processed 960 files.
# Processed 970 files.
# Processed 980 files.
# Processed 990 files.
# Processed 1000 files.
# Processed 1010 files.
# Processed 1020 files.
# Processed 1030 files.
# Processed 1040 files.
# Processed 1050 files.
# Processed 1060 files.
# Processed 1070 files.
# Processed 1080 files.
# Processed 1090 files.
# Processed 1100 files.
# Processed 1110 files.
# Processed 1120 files.
# Processed 1130 files.
# Processed 1140 files.
# Processed 1150 files.
# Processed 1160 files.
# Processed 1170 files.
# Processed 1180 files.
# Processed 1190 files.
# Processed 1200 files.
# Processed 1210 files.
# Processed 1220 files.
# Processed 1230 files.
# Processed 1240 files.
# Processed 1250 files.
# Processed 1260 files.
# Processed 1270 files.
# Processed 1280 files.
# Processed 1290 files.
# Processed 1300 files.
# Processed 1310 files.
# Processed 1320 files.
# Processed 1330 files.
# Processed 1340 files.
# Processed 1350 files.
# Processed 1360 files.
# Processed 1370 files.
# Processed 1380 files.
# Processed 1390 files.
# Processed 1400 files.
# Processed 1410 files.
# Processed 1420 files.
# Processed 1430 files.
# Processed 1440 files.
# Processed 1450 files.
# Processed 1460 files.
# Processed 1470 files.
# Processed 1480 files.
# Processed 1490 files.
# Processed 1500 files.
# Processed 1510 files.
# Processed 1520 files.
# Processed 1530 files.
# Processed 1540 files.
# Processed 1550 files.
# Processed 1560 files.
# Processed 1570 files.
# Processed 1580 files.
# Processed 1590 files.
# Processed 1600 files.
# Processed 1610 files.
# Processed 1620 files.
# Processed 1630 files.
# Processed 1640 files.
# Processed 1650 files.
# Processed 1660 files.
# Processed 1670 files.
# Processed 1680 files.
# Processed 1690 files.
# Processed 1700 files.
# Processed 1710 files.
# Processed 1720 files.
# Processed 1730 files.
# Processed 1740 files.
# Processed 1750 files.
# Processed 1760 files.
# Processed 1770 files.
# Processed 1780 files.
# Processed 1790 files.
# Processed 1800 files.
# Processed 1810 files.
# Processed 1820 files.
# Processed 1830 files.
# Processed 1840 files.
# Processed 1850 files.
# Processed 1860 files.
# Processed 1870 files.
# Processed 1880 files.
# Processed 1890 files.
# Processed 1900 files.
# Processed 1910 files.
# Processed 1920 files.
# Processed 1930 files.
# Processed 1940 files.
# Processed 1950 files.
# Processed 1960 files.
# Processed 1970 files.
# Processed 1980 files.
# Processed 1990 files.
# Processed 2000 files.
# Processed 2010 files.
# Processed 2020 files.
# Processed 2030 files.
# Processed 2040 files.
# Processed 2050 files.
# Processed 2060 files.
# Processed 2070 files.
# Processed 2080 files.
# Processed 2090 files.
# Processed 2100 files.
# Processed 2110 files.
# Processed 2120 files.
# Processed 2130 files.
# Processed 2140 files.
# Processed 2150 files.
# Processed 2160 files.
# Processed 2170 files.
# Processed 2180 files.
# Processed 2190 files.
# Processed 2200 files.
# Processed 2210 files.
# Processed 2220 files.
# Processed 2230 files.
# Processed 2240 files.
# Processed 2250 files.
# Processed 2260 files.
# Processed 2270 files.
# Processed 2280 files.
# Processed 2290 files.
# Processed 2300 files.
# Processed 2310 files.
# Processed 2320 files.
# Processed 2330 files.
# Processed 2340 files.
# Processed 2350 files.
# Processed 2360 files.
# Processed 2370 files.
# Processed 2380 files.
# Processed 2390 files.
# Processed 2400 files.
# Processed 2410 files.
# Processed 2420 files.
# Processed 2430 files.
# Processed 2440 files.
# Processed 2450 files.
# Processed 2460 files.
# Processed 2470 files.
# Processed 2480 files.
# Processed 2490 files.
# Processed 2500 files.
# Processed 2510 files.
# Processed 2520 files.
# Processed 2530 files.
# Processed 2540 files.
# Processed 2550 files.
# Processed 2560 files.
# Processed 2570 files.
# Processed 2580 files.
# Processed 2590 files.
# Processed 2600 files.
# Processed 2610 files.
# Processed 2620 files.
# Processed 2630 files.
# Processed 2640 files.
# Processed 2650 files.
# Processed 2660 files.
# Processed 2670 files.
# Processed 2680 files.
# Processed 2690 files.
# Processed 2700 files.
# Processed 2710 files.
# Processed 2720 files.
# Processed 2730 files.
# Processed 2740 files.
# Processed 2750 files.
# Processed 2760 files.
# Processed 2770 files.
# Processed 2780 files.
# Processed 2790 files.
# Processed 2800 files.
# Processed 2810 files.
# Processed 2820 files.
# Processed 2830 files.
# Processed 2840 files.
# Processed 2850 files.
# Processed 2860 files.
# Processed 2870 files.
# Processed 2880 files.
# Processed 2890 files.
# Processed 2900 files.
# Processed 2910 files.
# Processed 2920 files.
# Processed 2930 files.
# Processed 2940 files.
# Processed 2950 files.
# Processed 2960 files.
# Processed 2970 files.
# Processed 2980 files.
# Processed 2990 files.
# Processed 3000 files.
# Processed 3010 files.
# Processed 3020 files.
# Processed 3030 files.
# Processed 3040 files.
# Processed 3050 files.
# Processed 3060 files.
# Processed 3070 files.
# Processed 3080 files.
# Processed 3090 files.
# Processed 3100 files.
# Processed 3110 files.
# Processed 3120 files.
# Processed 3130 files.
# Processed 3140 files.
# Processed 3150 files.
# Processed 3160 files.
# Processed 3170 files.
# Processed 3180 files.
# Processed 3190 files.
# Processed 3200 files.
# Processed 3210 files.
# Processed 3220 files.
# Processed 3230 files.
# Processed 3240 files.
# Processed 3250 files.
# Processed 3260 files.
# Processed 3270 files.
# Processed 3280 files.
# Processed 3290 files.
# Processed 3300 files.
# Processed 3310 files.
# Processed 3320 files.
# Processed 3330 files.
# Processed 3340 files.
# Processed 3350 files.
# Processed 3360 files.
# Processed 3370 files.
# Processed 3380 files.
# Processed 3390 files.
# Processed 3400 files.
# Processed 3410 files.
# Processed 3420 files.
# Processed 3430 files.
# Processed 3440 files.
# Processed 3450 files.
# Processed 3460 files.
# Processed 3470 files.
# Processed 3480 files.
# Processed 3490 files.
# Processed 3500 files.
# Processed 3510 files.
# Processed 3520 files.
# Processed 3530 files.
# Processed 3540 files.
# Processed 3550 files.
# Processed 3560 files.
# Processed 3570 files.
# Processed 3580 files.
# Processed 3590 files.
# Processed 3600 files.
# Processed 3610 files.
# Processed 3620 files.
# Processed 3630 files.
# Processed 3640 files.
# Processed 3650 files.
# Processed 3660 files.
# Processed 3670 files.
# Processed 3680 files.
# Processed 3690 files.
# Processed 3700 files.
# Processed 3710 files.
# Processed 3720 files.
# Processed 3730 files.
# Processed 3740 files.
# Processed 3750 files.
# Processed 3760 files.
# Processed 3770 files.
# Processed 3780 files.
# Processed 3790 files.
# Processed 3800 files.
# Processed 3810 files.
# Processed 3820 files.
# Processed 3830 files.
# Processed 3840 files.
# Processed 3850 files.
# Processed 3860 files.
# Processed 3870 files.
# Processed 3880 files.
# Processed 3890 files.
# Processed 3900 files.
# Processed 3910 files.
# Processed 3920 files.
# Processed 3930 files.
# Processed 3940 files.
# Processed 3950 files.
# Processed 3960 files.
# Processed 3970 files.
# Processed 3980 files.
# Processed 3990 files.
# Processed 4000 files.
# Processed 4010 files.
# Processed 4020 files.
# Processed 4030 files.
# Processed 4040 files.
# Processed 4050 files.
# Processed 4060 files.
# Processed 4070 files.
# Processed 4080 files.
# Processed 4090 files.
# Processed 4100 files.
# Processed 4110 files.
# Processed 4120 files.
# Processed 4130 files.
# Processed 4140 files.
# Processed 4150 files.
# Processed 4160 files.
# Processed 4170 files.
# Processed 4180 files.
# Processed 4190 files.
# Processed 4200 files.
# Processed 4210 files.
# Processed 4220 files.
# Processed 4230 files.
# Processed 4240 files.
# Processed 4250 files.
# Processed 4260 files.
# Processed 4270 files.
# Processed 4280 files.
# Processed 4290 files.
# Processed 4300 files.
# Processed 4310 files.
# Processed 4320 files.
# Processed 4330 files.
# Processed 4340 files.
# Processed 4350 files.
# Processed 4360 files.
# Processed 4370 files.
# Processed 4380 files.
# Processed 4390 files.
# Processed 4400 files.
# Processed 4410 files.
# Processed 4420 files.
# Processed 4430 files.
# Processed 4440 files.
# Processed 4450 files.
# Processed 4460 files.
# Processed 4470 files.
# Processed 4480 files.
# Processed 4490 files.
# Processed 4500 files.
# Processed 4510 files.
# Processed 4520 files.
# Processed 4530 files.
# Processed 4540 files.
# Processed 4550 files.
# Processed 4560 files.
# Processed 4570 files.
# Processed 4580 files.
# Processed 4590 files.
# Processed 4600 files.
# Processed 4610 files.
# Processed 4620 files.
# Processed 4630 files.
# Processed 4640 files.
# Processed 4650 files.
# Processed 4660 files.
# Processed 4670 files.
# Processed 4680 files.
# Processed 4690 files.
# Processed 4700 files.
# Processed 4710 files.
# Processed 4720 files.
# Processed 4730 files.
# Processed 4740 files.
# Processed 4750 files.
# Processed 4760 files.
# Processed 4770 files.
# Processed 4780 files.
# Processed 4790 files.
# Processed 4800 files.
# Processed 4810 files.
# Processed 4820 files.
# Processed 4830 files.
# Processed 4840 files.
# Processed 4850 files.
# Processed 4860 files.
# Processed 4870 files.
# Processed 4880 files.
# Processed 4890 files.
# Processed 4900 files.
# Processed 4910 files.
# Processed 4920 files.
# Processed 4930 files.
# Processed 4940 files.
# Processed 4950 files.
# Processed 4960 files.
# Processed 4970 files.
# Processed 4980 files.
# Processed 4990 files.
# Processed 5000 files.
# Processed 5010 files.
# Processed 5020 files.
# Processed 5030 files.
# Processed 5040 files.
# Processed 5050 files.
# Processed 5060 files.
# Processed 5070 files.
# Processed 5080 files.
# Processed 5090 files.
# Processed 5100 files.
# Processed 5110 files.
# Processed 5120 files.
# Processed 5130 files.
# Processed 5140 files.
# Processed 5150 files.
# Processed 5160 files.
# Processed 5170 files.
# Processed 5180 files.
# Processed 5190 files.
# Processed 5200 files.
# Processed 5210 files.
# Processed 5220 files.
# Processed 5230 files.
# Processed 5240 files.
# Processed 5250 files.
# Processed 5260 files.
# Processed 5270 files.
# Processed 5280 files.
# Processed 5290 files.
# Processed 5300 files.
# Processed 5310 files.
# Processed 5320 files.
# Processed 5330 files.
# Processed 5340 files.
# Processed 5350 files.
# Processed 5360 files.
# Processed 5370 files.
# Processed 5380 files.
# Processed 5390 files.
# Processed 5400 files.
# Processed 5410 files.
# Processed 5420 files.
# Processed 5430 files.
# Processed 5440 files.
# Processed 5450 files.
# Processed 5460 files.
# Processed 5470 files.
# Processed 5480 files.
# Processed 5490 files.
# Processed 5500 files.
# Processed 5510 files.
# Processed 5520 files.
# Processed 5530 files.
# Processed 5540 files.
# Processed 5550 files.
# Processed 5560 files.
# Processed 5570 files.
# Processed 5580 files.
# Processed 5590 files.
# Processed 5600 files.
# Processed 5610 files.
# Processed 5620 files.
# Processed 5630 files.
# Processed 5640 files.
# Processed 5650 files.
# Processed 5660 files.
# Processed 5670 files.
# Processed 5680 files.
# Processed 5690 files.
# Processed 5700 files.
# Processed 5710 files.
# Processed 5720 files.
# Processed 5730 files.
# Processed 5740 files.
# Processed 5750 files.
# Processed 5760 files.
# Processed 5770 files.
# Processed 5780 files.
# Processed 5790 files.
# Processed 5800 files.
# Processed 5810 files.
# Processed 5820 files.
# Processed 5830 files.
# Processed 5840 files.
# Processed 5850 files.
# Processed 5860 files.
# Processed 5870 files.
# Processed 5880 files.
# Processed 5890 files.
# Processed 5900 files.
# Processed 5910 files.
# Processed 5920 files.
# Processed 5930 files.
# Processed 5940 files.
# Processed 5950 files.
# Processed 5960 files.
# Processed 5970 files.
# Processed 5980 files.
# Processed 5990 files.
# Processed 6000 files.
# Processed 6010 files.
# Processed 6020 files.
# Processed 6030 files.
# Processed 6040 files.
# Processed 6050 files.
# Processed 6060 files.
# Processed 6070 files.
# Processed 6080 files.
# Processed 6090 files.
# Processed 6100 files.
# Processed 6110 files.
# Processed 6120 files.
# Processed 6130 files.
# Processed 6140 files.
# Processed 6150 files.
# Processed 6160 files.
# Processed 6170 files.
# Processed 6180 files.
# Processed 6190 files.
# Processed 6200 files.
# Processed 6210 files.
# Processed 6220 files.
# Processed 6230 files.
# Processed 6240 files.
# Processed 6250 files.
# Processed 6260 files.
# Processed 6270 files.
# Processed 6280 files.
# Processed 6290 files.
# Processed 6300 files.
# Processed 6310 files.
# Processed 6320 files.
# Processed 6330 files.
# Processed 6340 files.
# Processed 6350 files.
# Processed 6360 files.
# Processed 6370 files.
# Processed 6380 files.
# Processed 6390 files.
# Processed 6400 files.
# Processed 6410 files.
# Processed 6420 files.
# Processed 6430 files.
# Processed 6440 files.
# Processed 6450 files.
# Processed 6460 files.
# Processed 6470 files.
# Processed 6480 files.
# Processed 6490 files.
# Processed 6500 files.
# Processed 6510 files.
# Processed 6520 files.
# Processed 6530 files.
# Processed 6540 files.
# Processed 6550 files.
# Processed 6560 files.
# Processed 6570 files.
# Processed 6580 files.
# Processed 6590 files.
# Processed 6600 files.
# Processed 6610 files.
# Processed 6620 files.
# Processed 6630 files.
# Processed 6640 files.
# Processed 6650 files.
# Processed 6660 files.
# Processed 6670 files.
# Processed 6680 files.
# Processed 6690 files.
# Processed 6700 files.
# Processed 6710 files.
# Processed 6720 files.
# Processed 6730 files.
# Processed 6740 files.
# Processed 6750 files.
# Processed 6760 files.
# Processed 6770 files.
# Processed 6780 files.
# Processed 6790 files.
# Processed 6800 files.
# Processed 6810 files.
# Processed 6820 files.
# Processed 6830 files.
# Processed 6840 files.
# Processed 6850 files.
# Processed 6860 files.
# Processed 6870 files.
# Processed 6880 files.
# Processed 6890 files.
# Processed 6900 files.
# Processed 6910 files.
# Processed 6920 files.
# Processed 6930 files.
# Processed 6940 files.
# Processed 6950 files.
# Processed 6960 files.
# Processed 6970 files.
# Processed 6980 files.
# Processed 6990 files.
# Processed 7000 files.
# Processed 7010 files.
# Processed 7020 files.
# Processed 7030 files.
# Processed 7040 files.
# Processed 7050 files.
# Processed 7060 files.
# Processed 7070 files.
# Processed 7080 files.
# Processed 7090 files.
# Processed 7100 files.
# Processed 7110 files.
# Processed 7120 files.
# Processed 7130 files.
# Processed 7140 files.
# Processed 7150 files.
# Processed 7160 files.
# Processed 7170 files.
# Processed 7180 files.
# Processed 7190 files.
# Processed 7200 files.
# Processed 7210 files.
# Processed 7220 files.
# Processed 7230 files.
# Processed 7240 files.
# Processed 7250 files.
# Processed 7260 files.
# Processed 7270 files.
# Processed 7280 files.
# Processed 7290 files.
# Processed 7300 files.
# Processed 7310 files.
# Processed 7320 files.
# Processed 7330 files.
# Processed 7340 files.
# Processed 7350 files.
# Processed 7360 files.
# Processed 7370 files.
# Processed 7380 files.
# Processed 7390 files.
# Processed 7400 files.
# Processed 7410 files.
# Processed 7420 files.
# Processed 7430 files.
# Processed 7440 files.
# Processed 7450 files.
# Processed 7460 files.
# Processed 7470 files.
# Processed 7480 files.
# Processed 7490 files.
# Processed 7500 files.
# Processed 7510 files.
# Processed 7520 files.
# Processed 7530 files.
# Processed 7540 files.
# Processed 7550 files.
# Processed 7560 files.
# Processed 7570 files.
# Processed 7580 files.
# Processed 7590 files.
# Processed 7600 files.
# Processed 7610 files.
# Processed 7620 files.
# Processed 7630 files.
# Processed 7640 files.
# Processed 7650 files.
# Processed 7660 files.
# Processed 7670 files.
# Processed 7680 files.
# Processed 7690 files.
# Processed 7700 files.
# Processed 7710 files.
# Processed 7720 files.
# Processed 7730 files.
# Processed 7740 files.
# Processed 7750 files.
# Processed 7760 files.
# Processed 7770 files.
# Processed 7780 files.
# Processed 7790 files.
# Processed 7800 files.
# Processed 7810 files.
# Processed 7820 files.
# Processed 7830 files.
# Processed 7840 files.
# Processed 7850 files.
# Processed 7860 files.
# Processed 7870 files.
# Processed 7880 files.
# Processed 7890 files.
# Processed 7900 files.
# Processed 7910 files.
# Processed 7920 files.
# Processed 7930 files.
# Processed 7940 files.
# Processed 7950 files.
# Processed 7960 files.
# Processed 7970 files.
# Processed 7980 files.
# Processed 7990 files.
# Processed 8000 files.
# Processed 8010 files.
# Processed 8020 files.
# Processed 8030 files.
# Processed 8040 files.
# Processed 8050 files.
# Processed 8060 files.
# Processed 8070 files.
# Processed 8080 files.
# Processed 8090 files.
# Processed 8100 files.
# Processed 8110 files.
# Processed 8120 files.
# Processed 8130 files.
# Processed 8140 files.
# Processed 8150 files.
# Processed 8160 files.
# Processed 8170 files.
# Processed 8180 files.
# Processed 8190 files.
# Processed 8200 files.
# Processed 8210 files.
# Processed 8220 files.
# Processed 8230 files.
# Processed 8240 files.
# Processed 8250 files.
# Processed 8260 files.
# Processed 8270 files.
# Processed 8280 files.
# Processed 8290 files.
# Processed 8300 files.
# Processed 8310 files.
# Processed 8320 files.
# Processed 8330 files.
# Processed 8340 files.
# Processed 8350 files.
# Processed 8360 files.
# Processed 8370 files.
# Processed 8380 files.
# Processed 8390 files.
# Processed 8400 files.
# Processed 8410 files.
# Processed 8420 files.
# Processed 8430 files.
# Processed 8440 files.
# Processed 8450 files.
# Processed 8460 files.
# Processed 8470 files.
# Processed 8480 files.
# Processed 8490 files.
# Processed 8500 files.
# Processed 8510 files.
# Processed 8520 files.
# Processed 8530 files.
# Processed 8540 files.
# Processed 8550 files.
# Processed 8560 files.
# Processed 8570 files.
# Processed 8580 files.
# Processed 8590 files.
# Processed 8600 files.
# Processed 8610 files.
# Processed 8620 files.
# Processed 8630 files.
# Processed 8640 files.
# Processed 8650 files.
# Processed 8660 files.
# Processed 8670 files.
# Processed 8680 files.
# Processed 8690 files.
# Processed 8700 files.
# Processed 8710 files.
# Processed 8720 files.
# Processed 8730 files.
# Processed 8740 files.
# Processed 8750 files.
# Processed 8760 files.
# Processed 8770 files.
# Processed 8780 files.
# Processed 8790 files.
# Processed 8800 files.
# Processed 8810 files.
# Processed 8820 files.
# Processed 8830 files.
# Processed 8840 files.
# Processed 8850 files.
# Processed 8860 files.
# Processed 8870 files.
# Processed 8880 files.
# Processed 8890 files.
# Processed 8900 files.
# Processed 8910 files.
# Processed 8920 files.
# Processed 8930 files.
# Processed 8940 files.
# Processed 8950 files.
# Processed 8960 files.
# Processed 8970 files.
# Processed 8980 files.
# Processed 8990 files.
# Processed 9000 files.
# Processed 9010 files.
# Processed 9020 files.
# Processed 9030 files.
# Processed 9040 files.
# Processed 9050 files.
# Processed 9060 files.
# Processed 9070 files.
# Processed 9080 files.
# Processed 9090 files.
# Processed 9100 files.
# Processed 9110 files.
# Processed 9120 files.
# Processed 9130 files.
# Processed 9140 files.
# Processed 9150 files.
# Processed 9160 files.
# Processed 9170 files.
# Processed 9180 files.
# Processed 9190 files.
# Processed 9200 files.
# Processed 9210 files.
# Processed 9220 files.
# Processed 9230 files.
# Processed 9240 files.
# Processed 9250 files.
# Processed 9260 files.
# Processed 9270 files.
# Processed 9280 files.
# Processed 9290 files.
# Processed 9300 files.
# Processed 9310 files.
# Processed 9320 files.
# Processed 9330 files.
# Processed 9340 files.
# Processed 9350 files.
# Processed 9360 files.
# Processed 9370 files.
# Processed 9380 files.
# Processed 9390 files.
# Processed 9400 files.
# Processed 9410 files.
# Processed 9420 files.
# Processed 9430 files.
# Processed 9440 files.
# Processed 9450 files.
# Processed 9460 files.
# Processed 9470 files.
# Processed 9480 files.
# Processed 9490 files.
# Processed 9500 files.
# Processed 9510 files.
# Processed 9520 files.
# Processed 9530 files.
# Processed 9540 files.
# Processed 9550 files.
# Processed 9560 files.
# Processed 9570 files.
# Processed 9580 files.
# Processed 9590 files.
# Processed 9600 files.
# Processed 9610 files.
# Processed 9620 files.
# Processed 9630 files.
# Processed 9640 files.
# Processed 9650 files.
# Processed 9660 files.
# Processed 9670 files.
# Processed 9680 files.
# Processed 9690 files.
# Processed 9700 files.
# Processed 9710 files.
# Processed 9720 files.
# Processed 9730 files.
# Processed 9740 files.
# Processed 9750 files.
# Processed 9760 files.
# Processed 9770 files.
# Processed 9780 files.
# Processed 9790 files.
# Processed 9800 files.
# Processed 9810 files.
# Processed 9820 files.
# Processed 9830 files.
# Processed 9840 files.
# Processed 9850 files.
# Processed 9860 files.
# Processed 9870 files.
# Processed 9880 files.
# Processed 9890 files.
# Processed 9900 files.
# Processed 9910 files.
# Processed 9920 files.
# Processed 9930 files.
# Processed 9940 files.
# Processed 9950 files.
# Processed 9960 files.
# Processed 9970 files.
# Processed 9980 files.
# Processed 9990 files.
# Processed 10000 files.
# Processed 10010 files.
# Processed 10020 files.
# Processed 10030 files.
# Processed 10040 files.
# Processed 10050 files.
# Processed 10060 files.
# Processed 10070 files.
# Processed 10080 files.
# Processed 10090 files.
# Processed 10100 files.
# Processed 10110 files.
# Processed 10120 files.
# Processed 10130 files.
# Processed 10140 files.
# Processed 10150 files.
# Processed 10160 files.
# Processed 10170 files.
# Processed 10180 files.
# Processed 10190 files.
# Processed 10200 files.
# Processed 10210 files.
# Processed 10220 files.
# Processed 10230 files.
# Processed 10240 files.
# Processed 10250 files.
# Processed 10260 files.
# Processed 10270 files.
# Processed 10280 files.
# Processed 10290 files.
# Processed 10300 files.
# Processed 10310 files.
# Processed 10320 files.
# Processed 10330 files.
# Processed 10340 files.
# Processed 10350 files.
# Processed 10360 files.
# Processed 10370 files.
# Processed 10380 files.
# Processed 10390 files.
# Processed 10400 files.
# Processed 10410 files.
# Processed 10420 files.
# Processed 10430 files.
# Processed 10440 files.
# Processed 10450 files.
# Processed 10460 files.
# Processed 10470 files.
# Processed 10480 files.
# Processed 10490 files.
# Processed 10500 files.
# Processed 10510 files.
# Processed 10520 files.
# Processed 10530 files.
# Processed 10540 files.
# Processed 10550 files.
# Processed 10560 files.
# Processed 10570 files.
# Processed 10580 files.
# Processed 10590 files.
# Processed 10600 files.
# Processed 10610 files.
# Processed 10620 files.
# Processed 10630 files.
# Processed 10640 files.
# Processed 10650 files.
# Processed 10660 files.
# Processed 10670 files.
# Processed 10680 files.
# Processed 10690 files.
# Processed 10700 files.
# Processed 10710 files.
# Processed 10720 files.
# Processed 10730 files.
# Processed 10740 files.
# Processed 10750 files.
# Processed 10760 files.
# Processed 10770 files.
# Processed 10780 files.
# Processed 10790 files.
# Processed 10800 files.
# Processed 10810 files.
# Processed 10820 files.
# Processed 10830 files.
# Processed 10840 files.
# Processed 10850 files.
# Processed 10860 files.
# Processed 10870 files.
# Processed 10880 files.
# Processed 10890 files.
# Processed 10900 files.
# Processed 10910 files.
# Processed 10920 files.
# Processed 10930 files.
# Processed 10940 files.
# Processed 10950 files.
# Processed 10960 files.
# Processed 10970 files.
# Processed 10980 files.
# Processed 10990 files.
# Processed 11000 files.
# Processed 11010 files.
# Processed 11020 files.
# Processed 11030 files.
# Processed 11040 files.
# Processed 11050 files.
# Processed 11060 files.
# Processed 11070 files.
# Processed 11080 files.
# Processed 11090 files.
# Processed 11100 files.
# Processed 11110 files.
# Processed 11120 files.
# Processed 11130 files.
# Processed 11140 files.
# Processed 11150 files.
# Processed 11160 files.
# Processed 11170 files.
# Processed 11180 files.
# Processed 11190 files.
# Processed 11200 files.
# Processed 11210 files.
# Processed 11220 files.
# Processed 11230 files.
# Processed 11240 files.
# Processed 11250 files.
# Processed 11260 files.
# Processed 11270 files.
# Processed 11280 files.
# Processed 11290 files.
# Processed 11300 files.
# Processed 11310 files.
# Processed 11320 files.
# Processed 11330 files.
# Processed 11340 files.
# Processed 11350 files.
# Processed 11360 files.
# Processed 11370 files.
# Processed 11380 files.
# Processed 11390 files.
# Processed 11400 files.
# Processed 11410 files.
# Processed 11420 files.
# Processed 11430 files.
# Processed 11440 files.
# Processed 11450 files.
# Processed 11460 files.
# Processed 11470 files.
# Processed 11480 files.
# Processed 11490 files.
# Processed 11500 files.
# Processed 11510 files.
# Processed 11520 files.
# Processed 11530 files.
# Processed 11540 files.
# Processed 11550 files.
# Processed 11560 files.
# Processed 11570 files.
# Processed 11580 files.
# Processed 11590 files.
# Processed 11600 files.
# Processed 11610 files.
# Processed 11620 files.
# Processed 11630 files.
# Processed 11640 files.
# Processed 11650 files.
# Processed 11660 files.
# Processed 11670 files.
# Processed 11680 files.
# Processed 11690 files.
# Processed 11700 files.
# Processed 11710 files.
# Processed 11720 files.
# Processed 11730 files.
# Processed 11740 files.
# Processed 11750 files.
# Processed 11760 files.
# Processed 11770 files.
# Processed 11780 files.
# Processed 11790 files.
# Processed 11800 files.
# Processed 11810 files.
# Processed 11820 files.
# Processed 11830 files.
# Processed 11840 files.
# Processed 11850 files.
# Processed 11860 files.
# Processed 11870 files.
# Processed 11880 files.
# Processed 11890 files.
# Processed 11900 files.
# Processed 11910 files.
# Processed 11920 files.
# Processed 11930 files.
# Processed 11940 files.
# Processed 11950 files.
# Processed 11960 files.
# Processed 11970 files.
# Processed 11980 files.
# Processed 11990 files.
# Processed 12000 files.
# Processed 12010 files.
# Processed 12020 files.
# Processed 12030 files.
# Processed 12040 files.
# Processed 12050 files.
# Processed 12060 files.
# Processed 12070 files.
# Processed 12080 files.
# Processed 12090 files.
# Processed 12100 files.
# Processed 12110 files.
# Processed 12120 files.
# Processed 12130 files.
# Processed 12140 files.
# Processed 12150 files.
# Processed 12160 files.
# Processed 12170 files.
# Processed 12180 files.
# Processed 12190 files.
# Processed 12200 files.
# Processed 12210 files.
# Processed 12220 files.
# Processed 12230 files.
# Processed 12240 files.
# Processed 12250 files.
# Processed 12260 files.
# Processed 12270 files.
# Processed 12280 files.
# Processed 12290 files.
# Processed 12300 files.
# Processed 12310 files.
# Processed 12320 files.
# Processed 12330 files.
# Processed 12340 files.
# Processed 12350 files.
# Processed 12360 files.
# Processed 12370 files.
# Processed 12380 files.
# Processed 12390 files.
# Processed 12400 files.
# Processed 12410 files.
# Processed 12420 files.
# Processed 12430 files.
# Processed 12440 files.
# Processed 12450 files.
# Processed 12460 files.
# Processed 12470 files.
# Processed 12480 files.
# Processed 12490 files.
# Processed 12500 files.
# Processed 12510 files.
# Processed 12520 files.
# Processed 12530 files.
# Processed 12540 files.
# Processed 12550 files.
# Processed 12560 files.
# Processed 12570 files.
# Processed 12580 files.
# Processed 12590 files.
# Processed 12600 files.
# Processed 12610 files.
# Processed 12620 files.
# Processed 12630 files.
# Processed 12640 files.
# Processed 12650 files.
# Processed 12660 files.
# Processed 12670 files.
# Processed 12680 files.
# Processed 12690 files.
# Processed 12700 files.
# Processed 12710 files.
# Processed 12720 files.
# Processed 12730 files.
# Processed 12740 files.
# Processed 12750 files.
# Processed 12760 files.
# Processed 12770 files.
# Processed 12780 files.
# Processed 12790 files.
# Processed 12800 files.
# Processed 12810 files.
# Processed 12820 files.
# Processed 12830 files.
# Processed 12840 files.
# Processed 12850 files.
# Processed 12860 files.
# Processed 12870 files.
# Processed 12880 files.
# Processed 12890 files.
# Processed 12900 files.
# Processed 12910 files.
# Processed 12920 files.
# Processed 12930 files.
# Processed 12940 files.
# Processed 12950 files.
# Processed 12960 files.
# Processed 12970 files.
# Processed 12980 files.
# Processed 12990 files.
# Processed 13000 files.
# Processed 13010 files.
# Processed 13020 files.
# Processed 13030 files.
# Processed 13040 files.
# Processed 13050 files.
# Processed 13060 files.
# Processed 13070 files.
# Processed 13080 files.
# Processed 13090 files.
# Processed 13100 files.
# Processed 13110 files.
# Processed 13120 files.
# Processed 13130 files.
# Processed 13140 files.
# Processed 13150 files.
# Processed 13160 files.
# Processed 13170 files.
# Processed 13180 files.
# Processed 13190 files.
# Processed 13200 files.
# Processed 13210 files.
# Processed 13220 files.
# Processed 13230 files.
# Processed 13240 files.
# Processed 13250 files.
# Processed 13260 files.
# Processed 13270 files.
# Processed 13280 files.
# Processed 13290 files.
# Processed 13300 files.
# Processed 13310 files.
# Processed 13320 files.
# Processed 13330 files.
# Processed 13340 files.
# Processed 13350 files.
# Processed 13360 files.
# Processed 13370 files.
# Processed 13380 files.
# Processed 13390 files.
# Processed 13400 files.
# Processed 13410 files.
# Processed 13420 files.
# Processed 13430 files.
# Processed 13440 files.
# Processed 13450 files.
# Processed 13460 files.
# Processed 13470 files.
# Processed 13480 files.
# Processed 13490 files.
# Processed 13500 files.
# Processed 13510 files.
# Processed 13520 files.
# Processed 13530 files.
# Processed 13540 files.
# Processed 13550 files.
# Processed 13560 files.
# Processed 13570 files.
# Processed 13580 files.
# Processed 13590 files.
# Processed 13600 files.
# Processed 13610 files.
# Processed 13620 files.
# Processed 13630 files.
# Processed 13640 files.
# Processed 13650 files.
# Processed 13660 files.
# Processed 13670 files.
# Processed 13680 files.
# Processed 13690 files.
# Processed 13700 files.
# Processed 13710 files.
# Processed 13720 files.
# Processed 13730 files.
# Processed 13740 files.
# Processed 13750 files.
# Processed 13760 files.
# Processed 13770 files.
# Processed 13780 files.
# Processed 13790 files.
# Processed 13800 files.
# Processed 13810 files.
# Processed 13820 files.
# Processed 13830 files.
# Processed 13840 files.
# Processed 13850 files.
# Processed 13860 files.
# Processed 13870 files.
# Processed 13880 files.
# Processed 13890 files.
# Processed 13900 files.
# Processed 13910 files.
# Processed 13920 files.
# Processed 13930 files.
# Processed 13940 files.
# Processed 13950 files.
# Processed 13960 files.
# Processed 13970 files.
# Processed 13980 files.
# Processed 13990 files.
# Processed 14000 files.
# Processed 14010 files.
# Processed 14020 files.
# Processed 14030 files.
# Processed 14040 files.
# Processed 14050 files.
# Processed 14060 files.
# Processed 14070 files.
# Processed 14080 files.
# Processed 14090 files.
# Processed 14100 files.
# Processed 14110 files.
# Processed 14120 files.
# Processed 14130 files.
# Processed 14140 files.
# Processed 14150 files.
# Processed 14160 files.
# Processed 14170 files.
# Processed 14180 files.
# Processed 14190 files.
# Processed 14200 files.
# Processed 14210 files.
# Processed 14220 files.
# Processed 14230 files.
# Processed 14240 files.
# Processed 14250 files.
# Processed 14260 files.
# Processed 14270 files.
# Processed 14280 files.
# Processed 14290 files.
# Processed 14300 files.
# Processed 14310 files.
# Processed 14320 files.
# Processed 14330 files.
# Processed 14340 files.
# Processed 14350 files.
# Processed 14360 files.
# Processed 14370 files.
# Processed 14380 files.
# Processed 14390 files.
# Processed 14400 files.
# Processed 14410 files.
# Processed 14420 files.
# Processed 14430 files.
# Processed 14440 files.
# Processed 14450 files.
# Processed 14460 files.
# Processed 14470 files.
# Processed 14480 files.
# Processed 14490 files.
# Processed 14500 files.
# Processed 14510 files.
# Processed 14520 files.
# Processed 14530 files.
# Processed 14540 files.
# Processed 14550 files.
# Processed 14560 files.
# Processed 14570 files.
# Processed 14580 files.
# Processed 14590 files.
# Processed 14600 files.
# Processed 14610 files.
# Processed 14620 files.
# Processed 14630 files.
# Processed 14640 files.
# Processed 14650 files.
# Processed 14660 files.
# Processed 14670 files.
# Processed 14680 files.
# Processed 14690 files.
# Processed 14700 files.
# Processed 14710 files.
# Processed 14720 files.
# Processed 14730 files.
# Processed 14740 files.
# Processed 14750 files.
# Processed 14760 files.
# Processed 14770 files.
# Processed 14780 files.
# Processed 14790 files.
# Processed 14800 files.
# Processed 14810 files.
# Processed 14820 files.
# Processed 14830 files.
# Processed 14840 files.
# Processed 14850 files.
# Processed 14860 files.
# Processed 14870 files.
# Processed 14880 files.
# Processed 14890 files.
# Processed 14900 files.
# Processed 14910 files.
# Processed 14920 files.
# Processed 14930 files.
# Processed 14940 files.
# Processed 14950 files.
# Processed 14960 files.
# Processed 14970 files.
# Processed 14980 files.
# Processed 14990 files.
# Processed 15000 files.
# Processed 15010 files.
# Processed 15020 files.
# Processed 15030 files.
# Processed 15040 files.
# Processed 15050 files.
# Processed 15060 files.
# Processed 15070 files.
# Processed 15080 files.
# Processed 15090 files.
# Processed 15100 files.
# Processed 15110 files.
# Processed 15120 files.
# Processed 15130 files.
# Processed 15140 files.
# Processed 15150 files.
# Processed 15160 files.
# Processed 15170 files.
# Processed 15180 files.
# Processed 15190 files.
# Processed 15200 files.
# Processed 15210 files.
# Processed 15220 files.
# Processed 15230 files.
# Processed 15240 files.
# Processed 15250 files.
# Processed 15260 files.
# Processed 15270 files.
# Processed 15280 files.
# Processed 15290 files.
# Processed 15300 files.
# Processed 15310 files.
# Processed 15320 files.
# Processed 15330 files.
# Processed 15340 files.
# Processed 15350 files.
# Processed 15360 files.
# Processed 15370 files.
# Processed 15380 files.
# Processed 15390 files.
# Processed 15400 files.
# Processed 15410 files.
# Processed 15420 files.
# Processed 15430 files.
# Processed 15440 files.
# Processed 15450 files.
# Processed 15460 files.
# Processed 15470 files.
# Processed 15480 files.
# Processed 15490 files.
# Processed 15500 files.
# Processed 15510 files.
# Processed 15520 files.
# Processed 15530 files.
# Processed 15540 files.
# Processed 15550 files.
# Processed 15560 files.
# Processed 15570 files.
# Processed 15580 files.
# Processed 15590 files.
# Processed 15600 files.
# Processed 15610 files.
# Processed 15620 files.
# Processed 15630 files.
# Processed 15640 files.
# Processed 15650 files.
# Processed 15660 files.
# Processed 15670 files.
# Processed 15680 files.
# Processed 15690 files.
# Processed 15700 files.
# Processed 15710 files.
# Processed 15720 files.
# Processed 15730 files.
# Processed 15740 files.
# Processed 15750 files.
# Processed 15760 files.
# Processed 15770 files.
# Processed 15780 files.
# Processed 15790 files.
# Processed 15800 files.
# Processed 15810 files.
# Processed 15820 files.
# Processed 15830 files.
# Processed 15840 files.
# Processed 15850 files.
# Processed 15860 files.
# Processed 15870 files.
# Processed 15880 files.
# Processed 15890 files.
# Processed 15900 files.
# Processed 15910 files.
# Processed 15920 files.
# Processed 15930 files.
# Processed 15940 files.
# Processed 15950 files.
# Processed 15960 files.
# Processed 15970 files.
# Processed 15980 files.
# Processed 15990 files.
# Processed 16000 files.
# Processed 16010 files.
# Processed 16020 files.
# Processed 16030 files.
# Processed 16040 files.
# Processed 16050 files.
# Processed 16060 files.
# Processed 16070 files.
# Processed 16080 files.
# Processed 16090 files.
# Processed 16100 files.
# Processed 16110 files.
# Processed 16120 files.
# Processed 16130 files.
# Processed 16140 files.
# Processed 16150 files.
# Processed 16160 files.
# Processed 16170 files.
# Processed 16180 files.
# Processed 16190 files.
# Processed 16200 files.
# Processed 16210 files.
# Processed 16220 files.
# Processed 16230 files.
# Processed 16240 files.
# Processed 16250 files.
# Processed 16260 files.
# Processed 16270 files.
# Processed 16280 files.
# Processed 16290 files.
# Processed 16300 files.
# Processed 16310 files.
# Processed 16320 files.
# Processed 16330 files.
# Processed 16340 files.
# Processed 16350 files.
# Processed 16360 files.
# Processed 16370 files.
# Processed 16380 files.
# Processed 16390 files.
# Processed 16400 files.
# Processed 16410 files.
# Processed 16420 files.
# Processed 16430 files.
# Processed 16440 files.
# Processed 16450 files.
# Processed 16460 files.
# Processed 16470 files.
# Processed 16480 files.
# Processed 16490 files.
# Processed 16500 files.
# Processed 16510 files.
# Processed 16520 files.
# Processed 16530 files.
# Processed 16540 files.
# Processed 16550 files.
# Processed 16560 files.
# Processed 16570 files.
# Processed 16580 files.
# Processed 16590 files.
# Processed 16600 files.
# Processed 16610 files.
# Processed 16620 files.
# Processed 16630 files.
# Processed 16640 files.
# Processed 16650 files.
# Processed 16660 files.
# Processed 16670 files.
# Processed 16680 files.
# Processed 16690 files.
# Processed 16700 files.
# Processed 16710 files.
# Processed 16720 files.
# Processed 16730 files.
# Processed 16740 files.
# Processed 16750 files.
# Processed 16760 files.
# Processed 16770 files.
# Processed 16780 files.
# Processed 16790 files.
# Processed 16800 files.
# Processed 16810 files.
# Processed 16820 files.
# Processed 16830 files.
# Processed 16840 files.
# Processed 16850 files.
# Processed 16860 files.
# Processed 16870 files.
# Processed 16880 files.
# Processed 16890 files.
# Processed 16900 files.
# Processed 16910 files.
# Processed 16920 files.
# Processed 16930 files.
# Processed 16940 files.
# Processed 16950 files.
# Processed 16960 files.
# Processed 16970 files.
# Processed 16980 files.
# Processed 16990 files.
# Processed 17000 files.
# Processed 17010 files.
# Processed 17020 files.
# Processed 17030 files.
# Processed 17040 files.
# Processed 17050 files.
# Processed 17060 files.
# Processed 17070 files.
# Processed 17080 files.
# Processed 17090 files.
# Processed 17100 files.
# Processed 17110 files.
# Processed 17120 files.
# Processed 17130 files.
# Processed 17140 files.
# Processed 17150 files.
# Processed 17160 files.
# Processed 17170 files.
# Processed 17180 files.
# Processed 17190 files.
# Processed 17200 files.
# Processed 17210 files.
# Processed 17220 files.
# Processed 17230 files.
# Processed 17240 files.
# Processed 17250 files.
# Processed 17260 files.
# Processed 17270 files.
# Processed 17280 files.
# Processed 17290 files.
# Processed 17300 files.
# Processed 17310 files.
# Processed 17320 files.
# Processed 17330 files.
# Processed 17340 files.
# Processed 17350 files.
# Processed 17360 files.
# Processed 17370 files.
# Processed 17380 files.
# Processed 17390 files.
# Processed 17400 files.
# Processed 17410 files.
# Processed 17420 files.
# Processed 17430 files.
# Processed 17440 files.
# Processed 17450 files.
# Processed 17460 files.
# Processed 17470 files.
# Processed 17480 files.
# Processed 17490 files.
# Processed 17500 files.
# Processed 17510 files.
# Processed 17520 files.
# Processed 17530 files.
# Processed 17540 files.
# Processed 17550 files.
# Processed 17560 files.
# Processed 17570 files.
# Processed 17580 files.
# Processed 17590 files.
# Processed 17600 files.
# Processed 17610 files.
# Processed 17620 files.
# Processed 17630 files.
# Processed 17640 files.
# Processed 17650 files.
# Processed 17660 files.
# Processed 17670 files.
# Processed 17680 files.
# Processed 17690 files.
# Processed 17700 files.
# Processed 17710 files.
# Processed 17720 files.
# Processed 17730 files.
# Processed 17740 files.
# Processed 17750 files.
# Processed 17760 files.
# Processed 17770 files.
# Processed 17780 files.
# Processed 17790 files.
# Processed 17800 files.
# Processed 17810 files.
# Processed 17820 files.
# Processed 17830 files.
# Processed 17840 files.
# Processed 17850 files.
# Processed 17860 files.
# Processed 17870 files.
# Processed 17880 files.
# Processed 17890 files.
# Processed 17900 files.
# Processed 17910 files.
# Processed 17920 files.
# Processed 17930 files.
# Processed 17940 files.
# Processed 17950 files.
# Processed 17960 files.
# Processed 17970 files.
# Processed 17980 files.
# Processed 17990 files.
# Processed 18000 files.
# Processed 18010 files.
# Processed 18020 files.
# Processed 18030 files.
# Processed 18040 files.
# Processed 18050 files.
# Processed 18060 files.
# Processed 18070 files.
# Processed 18080 files.
# Processed 18090 files.
# Processed 18100 files.
# Processed 18110 files.
# Processed 18120 files.
# Processed 18130 files.
# Processed 18140 files.
# Processed 18150 files.
# Processed 18160 files.
# Processed 18170 files.
# Processed 18180 files.
# Processed 18190 files.
# Processed 18200 files.
# Processed 18210 files.
# Processed 18220 files.
# Processed 18230 files.
# Processed 18240 files.
# Processed 18250 files.
# Processed 18260 files.
# Processed 18270 files.
# Processed 18280 files.
# Processed 18290 files.
# Processed 18300 files.
# Processed 18310 files.
# Processed 18320 files.
# Processed 18330 files.
# Processed 18340 files.
# Processed 18350 files.
# Processed 18360 files.
# Processed 18370 files.
# Processed 18380 files.
# Processed 18390 files.
# Processed 18400 files.
# Processed 18410 files.
# Processed 18420 files.
# Processed 18430 files.
# Processed 18440 files.
# Processed 18450 files.
# Processed 18460 files.
# Processed 18470 files.
# Processed 18480 files.
# Processed 18490 files.
# Processed 18500 files.
# Processed 18510 files.
# Processed 18520 files.
# Processed 18530 files.
# Processed 18540 files.
# Processed 18550 files.
# Processed 18560 files.
# Processed 18570 files.
# Processed 18580 files.
# Processed 18590 files.
# Processed 18600 files.
# Processed 18610 files.
# Processed 18620 files.
# Processed 18630 files.
# Processed 18640 files.
# Processed 18650 files.
# Processed 18660 files.
# Processed 18670 files.
# Processed 18680 files.
# Processed 18690 files.
# Processed 18700 files.
# Processed 18710 files.
# Processed 18720 files.
# Processed 18730 files.
# Processed 18740 files.
# Processed 18750 files.
# Processed 18760 files.
# Processed 18770 files.
# Processed 18780 files.
# Processed 18790 files.
# Processed 18800 files.
# Processed 18810 files.
# Processed 18820 files.
# Processed 18830 files.
# Processed 18840 files.
# Processed 18850 files.
# Processed 18860 files.
# Processed 18870 files.
# Processed 18880 files.
# Processed 18890 files.
# Processed 18900 files.
# Processed 18910 files.
# Processed 18920 files.
# Processed 18930 files.
# Processed 18940 files.
# Processed 18950 files.
# Processed 18960 files.
# Processed 18970 files.
# Processed 18980 files.
# Processed 18990 files.
# Processed 19000 files.
# Processed 19010 files.
# Processed 19020 files.
# Processed 19030 files.
# Processed 19040 files.
# Processed 19050 files.
# Processed 19060 files.
# Processed 19070 files.
# Processed 19080 files.
# Processed 19090 files.
# Processed 19100 files.
# Processed 19110 files.
# Processed 19120 files.
# Processed 19130 files.
# Processed 19140 files.
# Processed 19150 files.
# Processed 19160 files.
# Processed 19170 files.
# Processed 19180 files.
# Processed 19190 files.
# Processed 19200 files.
# Processed 19210 files.
# Processed 19220 files.
# Processed 19230 files.
# Processed 19240 files.
# Processed 19250 files.
# Processed 19260 files.
# Processed 19270 files.
# Processed 19280 files.
# Processed 19290 files.
# Processed 19300 files.
# Processed 19310 files.
# Processed 19320 files.
# Processed 19330 files.
# Processed 19340 files.
# Processed 19350 files.
# Processed 19360 files.
# Processed 19370 files.
# Processed 19380 files.
# Processed 19390 files.
# Processed 19400 files.
# Processed 19410 files.
# Processed 19420 files.
# Processed 19430 files.
# Processed 19440 files.
# Processed 19450 files.
# Processed 19460 files.
# Processed 19470 files.
# Processed 19480 files.
# Processed 19490 files.
# Processed 19500 files.
# Processed 19510 files.
# Processed 19520 files.
# Processed 19530 files.
# Processed 19540 files.
# Processed 19550 files.
# Processed 19560 files.
# Processed 19570 files.
# Processed 19580 files.
# Processed 19590 files.
# Processed 19600 files.
# Processed 19610 files.
# Processed 19620 files.
# Processed 19630 files.
# Processed 19640 files.
# Processed 19650 files.
# Processed 19660 files.
# Processed 19670 files.
# Processed 19680 files.
# Processed 19690 files.
# Processed 19700 files.
# Processed 19710 files.
# Processed 19720 files.
# Processed 19730 files.
# Processed 19740 files.
# Processed 19750 files.
# Processed 19760 files.
# Processed 19770 files.
# Processed 19780 files.
# Processed 19790 files.
# Processed 19800 files.
# Processed 19810 files.
# Processed 19820 files.
# Processed 19830 files.
# Processed 19840 files.
# Processed 19850 files.
# Processed 19860 files.
# Processed 19870 files.
# Processed 19880 files.
# Processed 19890 files.
# Processed 19900 files.
# Processed 19910 files.
# Processed 19920 files.
# Processed 19930 files.
# Processed 19940 files.
# Processed 19950 files.
# Processed 19960 files.
# Processed 19970 files.
# Processed 19980 files.
# Processed 19990 files.
# Processed 20000 files.
# Processed 20010 files.
# Processed 20020 files.
# Processed 20030 files.
# Processed 20040 files.
# Processed 20050 files.
# Processed 20060 files.
# Processed 20070 files.
# Processed 20080 files.
# Processed 20090 files.
# Processed 20100 files.
# Processed 20110 files.
# Processed 20120 files.
# Processed 20130 files.
# Processed 20140 files.
# Processed 20150 files.
# Processed 20160 files.
# Processed 20170 files.
# Processed 20180 files.
# Processed 20190 files.
# Processed 20200 files.
# Processed 20210 files.
# Processed 20220 files.
# Processed 20230 files.
# Processed 20240 files.
# Processed 20250 files.
# Processed 20260 files.
# Processed 20270 files.
# Processed 20280 files.
# Processed 20290 files.
# Processed 20300 files.
# Processed 20310 files.
# Processed 20320 files.
# Processed 20330 files.
# Processed 20340 files.
# Processed 20350 files.
# Processed 20360 files.
# Processed 20370 files.
# Processed 20380 files.
# Processed 20390 files.
# Processed 20400 files.
# Processed 20410 files.
# Processed 20420 files.
# Processed 20430 files.
# Processed 20440 files.
# Processed 20450 files.
# Processed 20460 files.
# Processed 20470 files.
# Processed 20480 files.
# Processed 20490 files.
# Processed 20500 files.
# Processed 20510 files.
# Processed 20520 files.
# Processed 20530 files.
# Processed 20540 files.
# Processed 20550 files.
# Processed 20560 files.
# Processed 20570 files.
# Processed 20580 files.
# Processed 20590 files.
# Processed 20600 files.
# Processed 20610 files.
# Processed 20620 files.
# Processed 20630 files.
# Processed 20640 files.
# Processed 20650 files.
# Processed 20660 files.
# Processed 20670 files.
# Processed 20680 files.
# Processed 20690 files.
# Processed 20700 files.
# Processed 20710 files.
# Processed 20720 files.
# Processed 20730 files.
# Processed 20740 files.
# Processed 20750 files.
# Processed 20760 files.
# Processed 20770 files.
# Processed 20780 files.
# Processed 20790 files.
# Processed 20800 files.
# Processed 20810 files.
# Processed 20820 files.
# Processed 20830 files.
# Processed 20840 files.
# Processed 20850 files.
# Processed 20860 files.
# Processed 20870 files.
# Processed 20880 files.
# Processed 20890 files.
# Processed 20900 files.
# Processed 20910 files.
# Processed 20920 files.
# Processed 20930 files.
# Processed 20940 files.
# Processed 20950 files.
# Processed 20960 files.
# Processed 20970 files.
# Processed 20980 files.
# Processed 20990 files.
# Processed 21000 files.
# Processed 21010 files.
# Processed 21020 files.
# Processed 21030 files.
# Processed 21040 files.
# Processed 21050 files.
# Processed 21060 files.
# Processed 21070 files.
# Processed 21080 files.
# Processed 21090 files.
# Processed 21100 files.
# Processed 21110 files.
# Processed 21120 files.
# Processed 21130 files.
# Processed 21140 files.
# Processed 21150 files.
# Processed 21160 files.
# Processed 21170 files.
# Processed 21180 files.
# Processed 21190 files.
# Processed 21200 files.
# Processed 21210 files.
# Processed 21220 files.
# Processed 21230 files.
# Processed 21240 files.
# Processed 21250 files.
# Processed 21260 files.
# Processed 21270 files.
# Processed 21280 files.
# Processed 21290 files.
# Processed 21300 files.
# Processed 21310 files.
# Processed 21320 files.
# Processed 21330 files.
# Processed 21340 files.
# Processed 21350 files.
# ...
# Processed 897610 files.
# Processed 897620 files.
# Processed 897630 files.
# Processed 897640 files.
# Processed 897650 files.
# Processed 897660 files.
# Processed 897670 files.
# Processed 897680 files.
# Processed 897690 files.
# Processed 897700 files.
# Processed 897710 files.
# Processed 897720 files.
# Processed 897730 files.
# Processed 897740 files.
# Processed 897750 files.
# Processed 897760 files.
# Processed 897770 files.
# Processed 897780 files.
# Processed 897790 files.
# Processed 897800 files.
# Processed 897810 files.
# Processed 897820 files.
# Processed 897830 files.
# Processed 897840 files.
# Processed 897850 files.
# Processed 897860 files.
# Processed 897870 files.
# Processed 897880 files.
# Processed 897890 files.
# Processed 897900 files.
# Processed 897910 files.
# Processed 897920 files.
# Processed 897930 files.
# Processed 897940 files.
# Processed 897950 files.
# Processed 897960 files.
# Processed 897970 files.
# Processed 897980 files.
# Processed 897990 files.
# Processed 898000 files.
# Processed 898010 files.
# Processed 898020 files.
# Processed 898030 files.
# Processed 898040 files.
# Processed 898050 files.
# Processed 898060 files.
# Processed 898070 files.
# Processed 898080 files.
# Processed 898090 files.
# Processed 898100 files.
# Processed 898110 files.
# Processed 898120 files.
# Processed 898130 files.
# Processed 898140 files.
# Processed 898150 files.
# Processed 898160 files.
# Processed 898170 files.
# Processed 898180 files.
# Processed 898190 files.
# Processed 898200 files.
# Processed 898210 files.
# Processed 898220 files.
# Processed 898230 files.
# Processed 898240 files.
# Processed 898250 files.
# Processed 898260 files.
# Processed 898270 files.
# Processed 898280 files.
# Processed 898290 files.
# Processed 898300 files.
# Processed 898310 files.
# Processed 898320 files.
# Processed 898330 files.
# Processed 898340 files.
# Processed 898350 files.
# Processed 898360 files.
# Processed 898370 files.
# Processed 898380 files.
# Processed 898390 files.
# Processed 898400 files.
# Processed 898410 files.
# Processed 898420 files.
# Processed 898430 files.
# Processed 898440 files.
# Processed 898450 files.
# Processed 898460 files.
# Processed 898470 files.
# Processed 898480 files.
# Processed 898490 files.
# Processed 898500 files.
# Processed 898510 files.
# Processed 898520 files.
# Processed 898530 files.
# Processed 898540 files.
# Processed 898550 files.
# Processed 898560 files.
# Processed 898570 files.
# Processed 898580 files.
# Processed 898590 files.
# Processed 898600 files.
# Processed 898610 files.
# Processed 898620 files.
# Processed 898630 files.
# Processed 898640 files.
# Processed 898650 files.
# Processed 898660 files.
# Processed 898670 files.
# Processed 898680 files.
# Processed 898690 files.
# Processed 898700 files.
# Processed 898710 files.
# Processed 898720 files.
# Processed 898730 files.
# Processed 898740 files.
# Processed 898750 files.
# Processed 898760 files.
# Processed 898770 files.
# Processed 898780 files.
# Processed 898790 files.
# Processed 898800 files.
# Processed 898810 files.
# Processed 898820 files.
# Processed 898830 files.
# Processed 898840 files.
# Processed 898850 files.
# Processed 898860 files.
# Processed 898870 files.
# Processed 898880 files.
# Processed 898890 files.
# Processed 898900 files.
# Processed 898910 files.
# Processed 898920 files.
# Processed 898930 files.
# Processed 898940 files.
# Processed 898950 files.
# Processed 898960 files.
# Processed 898970 files.
# Processed 898980 files.
# Processed 898990 files.
# Processed 899000 files.
# Processed 899010 files.
# Processed 899020 files.
# Processed 899030 files.
# Processed 899040 files.
# Processed 899050 files.
# Processed 899060 files.
# Processed 899070 files.
# Processed 899080 files.
# Processed 899090 files.
# Processed 899100 files.
# Processed 899110 files.
# Processed 899120 files.
# Processed 899130 files.
# Processed 899140 files.
# Processed 899150 files.
# Processed 899160 files.
# Processed 899170 files.
# Processed 899180 files.
# Processed 899190 files.
# Processed 899200 files.
# Processed 899210 files.
# Processed 899220 files.
# Processed 899230 files.
# Processed 899240 files.
# Processed 899250 files.
# Processed 899260 files.
# Processed 899270 files.
# Processed 899280 files.
# Processed 899290 files.
# Processed 899300 files.
# Processed 899310 files.
# Processed 899320 files.
# Processed 899330 files.
# Processed 899340 files.
# Processed 899350 files.
# Processed 899360 files.
# Processed 899370 files.
# Processed 899380 files.
# Processed 899390 files.
# Processed 899400 files.
# Processed 899410 files.
# Processed 899420 files.
# Processed 899430 files.
# Processed 899440 files.
# Processed 899450 files.
# Processed 899460 files.
# Processed 899470 files.
# Processed 899480 files.
# Processed 899490 files.
# Processed 899500 files.
# Processed 899510 files.
# Processed 899520 files.
# Processed 899530 files.
# Processed 899540 files.
# Processed 899550 files.
# Processed 899560 files.
# Processed 899570 files.
# Processed 899580 files.
# Processed 899590 files.
# Processed 899600 files.
# Processed 899610 files.
# Processed 899620 files.
# Processed 899630 files.
# Processed 899640 files.
# Processed 899650 files.
# Processed 899660 files.
# Processed 899670 files.
# Processed 899680 files.
# Processed 899690 files.
# Processed 899700 files.
# Processed 899710 files.
# Processed 899720 files.
# Processed 899730 files.
# Processed 899740 files.
# Processed 899750 files.
# Processed 899760 files.
# Processed 899770 files.
# Processed 899780 files.
# Processed 899790 files.
# Processed 899800 files.
# Processed 899810 files.
# Processed 899820 files.
# Processed 899830 files.
# Processed 899840 files.
# Processed 899850 files.
# Processed 899860 files.
# Processed 899870 files.
# Processed 899880 files.
# Processed 899890 files.
# Processed 899900 files.
# Processed 899910 files.
# Processed 899920 files.
# Processed 899930 files.
# Processed 899940 files.
# Processed 899950 files.
# Processed 899960 files.
# Processed 899970 files.
# Processed 899980 files.
# Processed 899990 files.
# Processed 900000 files.
# Processed 900010 files.
# Processed 900020 files.
# Processed 900030 files.
# Processed 900040 files.
# Processed 900050 files.
# Processed 900060 files.
# Processed 900070 files.
# Processed 900080 files.
# Processed 900090 files.
# Processed 900100 files.
# Processed 900110 files.
# Processed 900120 files.
# Processed 900130 files.
# Processed 900140 files.
# Processed 900150 files.
# Processed 900160 files.
# Processed 900170 files.
# Processed 900180 files.
# Processed 900190 files.
# Processed 900200 files.
# Processed 900210 files.
# Processed 900220 files.
# Processed 900230 files.
# Processed 900240 files.
# Processed 900250 files.
# Processed 900260 files.
# Processed 900270 files.
# Processed 900280 files.
# Processed 900290 files.
# Processed 900300 files.
# Processed 900310 files.
# Processed 900320 files.
# Processed 900330 files.
# Processed 900340 files.
# Processed 900350 files.
# Processed 900360 files.
# Processed 900370 files.
# Processed 900380 files.
# Processed 900390 files.
# Processed 900400 files.
# Processed 900410 files.
# Processed 900420 files.
# Processed 900430 files.
# Processed 900440 files.
# Processed 900450 files.
# Processed 900460 files.
# Processed 900470 files.
# Processed 900480 files.
# Processed 900490 files.
# Processed 900500 files.
# Processed 900510 files.
# Processed 900520 files.
# Processed 900530 files.
# Processed 900540 files.
# Processed 900550 files.
# Processed 900560 files.
# Processed 900570 files.
# Processed 900580 files.
# Processed 900590 files.
# Processed 900600 files.
# Processed 900610 files.
# Processed 900620 files.
# Processed 900630 files.
# Processed 900640 files.
# Processed 900650 files.
# Processed 900660 files.
# Processed 900670 files.
# Processed 900680 files.
# Processed 900690 files.
# Processed 900700 files.
# Processed 900710 files.
# Processed 900720 files.
# Processed 900730 files.
# Processed 900740 files.
# Processed 900750 files.
# Processed 900760 files.
# Processed 900770 files.
# Processed 900780 files.
# Processed 900790 files.
# Processed 900800 files.
# Processed 900810 files.
# Processed 900820 files.
# Processed 900830 files.
# Processed 900840 files.
# Processed 900850 files.
# Processed 900860 files.
# Processed 900870 files.
# Processed 900880 files.
# Processed 900890 files.
# Processed 900900 files.
# Processed 900910 files.
# Processed 900920 files.
# Processed 900930 files.
# Processed 900940 files.
# Processed 900950 files.
# Processed 900960 files.
# Processed 900970 files.
# Processed 900980 files.
# Processed 900990 files.
# Processed 901000 files.
# Processed 901010 files.
# Processed 901020 files.
# Processed 901030 files.
# Processed 901040 files.
# Processed 901050 files.
# Processed 901060 files.
# Processed 901070 files.
# Processed 901080 files.
# Processed 901090 files.
# Processed 901100 files.
# Processed 901110 files.
# Processed 901120 files.
# Processed 901130 files.
# Processed 901140 files.
# Processed 901150 files.
# Processed 901160 files.
# Processed 901170 files.
# Processed 901180 files.
# Processed 901190 files.
# Processed 901200 files.
# Processed 901210 files.
# Processed 901220 files.
# Processed 901230 files.
# Processed 901240 files.
# Processed 901250 files.
# Processed 901260 files.
# Processed 901270 files.
# Processed 901280 files.
# Processed 901290 files.
# Processed 901300 files.
# Processed 901310 files.
# Processed 901320 files.
# Processed 901330 files.
# Processed 901340 files.
# Processed 901350 files.
# Processed 901360 files.
# Processed 901370 files.
# Processed 901380 files.
# Processed 901390 files.
# Processed 901400 files.
# Processed 901410 files.
# Processed 901420 files.
# Processed 901430 files.
# Processed 901440 files.
# Processed 901450 files.
# Processed 901460 files.
# Processed 901470 files.
# Processed 901480 files.
# Processed 901490 files.
# Processed 901500 files.
# Processed 901510 files.
# Processed 901520 files.
# Processed 901530 files.
# Processed 901540 files.
# Processed 901550 files.
# Processed 901560 files.
# Processed 901570 files.
# Processed 901580 files.
# Processed 901590 files.
# Processed 901600 files.
# Processed 901610 files.
# Processed 901620 files.
# Processed 901630 files.
# Processed 901640 files.
# Processed 901650 files.
# Processed 901660 files.
# Processed 901670 files.
# Processed 901680 files.
# Processed 901690 files.
# Processed 901700 files.
# Processed 901710 files.
# Processed 901720 files.
# Processed 901730 files.
# Processed 901740 files.
# Processed 901750 files.
# Processed 901760 files.
# Processed 901770 files.
# Processed 901780 files.
# Processed 901790 files.
# Processed 901800 files.
# Processed 901810 files.
# Processed 901820 files.
# Processed 901830 files.
# Processed 901840 files.
# Processed 901850 files.
# Processed 901860 files.
# Processed 901870 files.
# Processed 901880 files.
# Processed 901890 files.
# Processed 901900 files.
# Processed 901910 files.
# Processed 901920 files.
# Processed 901930 files.
# Processed 901940 files.
# Processed 901950 files.
# Processed 901960 files.
# Processed 901970 files.
# Processed 901980 files.
# Processed 901990 files.
# Processed 902000 files.
# Processed 902010 files.
# Processed 902020 files.
# Processed 902030 files.
# Processed 902040 files.
# Processed 902050 files.
# Processed 902060 files.
# Processed 902070 files.
# Processed 902080 files.
# Processed 902090 files.
# Processed 902100 files.
# Processed 902110 files.
# Processed 902120 files.
# Processed 902130 files.
# Processed 902140 files.
# Processed 902150 files.
# Processed 902160 files.
# Processed 902170 files.
# Processed 902180 files.
# Processed 902190 files.
# Processed 902200 files.
# Processed 902210 files.
# Processed 902220 files.
# Processed 902230 files.
# Processed 902240 files.
# Processed 902250 files.
# Processed 902260 files.
# Processed 902270 files.
# Processed 902280 files.
# Processed 902290 files.
# Processed 902300 files.
# Processed 902310 files.
# Processed 902320 files.
# Processed 902330 files.
# Processed 902340 files.
# Processed 902350 files.
# Processed 902360 files.
# Processed 902370 files.
# Processed 902380 files.
# Processed 902390 files.
# Processed 902400 files.
# Processed 902410 files.
# Processed 902420 files.
# Processed 902430 files.
# Processed 902440 files.
# Processed 902450 files.
# Processed 902460 files.
# Processed 902470 files.
# Processed 902480 files.
# Processed 902490 files.
# Processed 902500 files.
# Processed 902510 files.
# Processed 902520 files.
# Processed 902530 files.
# Processed 902540 files.
# Processed 902550 files.
# Processed 902560 files.
# Processed 902570 files.
# Processed 902580 files.
# Processed 902590 files.
# Processed 902600 files.
# Processed 902610 files.
# Processed 902620 files.
# Processed 902630 files.
# Processed 902640 files.
# Processed 902650 files.
# Processed 902660 files.
# Processed 902670 files.
# Processed 902680 files.
# Processed 902690 files.
# Processed 902700 files.
# Processed 902710 files.
# Processed 902720 files.
# Processed 902730 files.
# Processed 902740 files.
# Processed 902750 files.
# Processed 902760 files.
# Processed 902770 files.
# Processed 902780 files.
# Processed 902790 files.
# Processed 902800 files.
# Processed 902810 files.
# Processed 902820 files.
# Processed 902830 files.
# Processed 902840 files.
# Processed 902850 files.
# Processed 902860 files.
# Processed 902870 files.
# Processed 902880 files.
# Processed 902890 files.
# Processed 902900 files.
# Processed 902910 files.
# Processed 902920 files.
# Processed 902930 files.
# Processed 902940 files.
# Processed 902950 files.
# Processed 902960 files.
# Processed 902970 files.
# Processed 902980 files.
# Processed 902990 files.
# Processed 903000 files.
# Processed 903010 files.
# Processed 903020 files.
# Processed 903030 files.
# Processed 903040 files.
# Processed 903050 files.
# Processed 903060 files.
# Processed 903070 files.
# Processed 903080 files.
# Processed 903090 files.
# Processed 903100 files.
# Processed 903110 files.
# Processed 903120 files.
# Processed 903130 files.
# Processed 903140 files.
# Processed 903150 files.
# Processed 903160 files.
# Processed 903170 files.
# Processed 903180 files.
# Processed 903190 files.
# Processed 903200 files.
# Processed 903210 files.
# Processed 903220 files.
# Processed 903230 files.
# Processed 903240 files.
# Processed 903250 files.
# Processed 903260 files.
# Processed 903270 files.
# Processed 903280 files.
# Processed 903290 files.
# Processed 903300 files.
# Processed 903310 files.
# Processed 903320 files.
# Processed 903330 files.
# Processed 903340 files.
# Processed 903350 files.
# Processed 903360 files.
# Processed 903370 files.
# Processed 903380 files.
# Processed 903390 files.
# Processed 903400 files.
# Processed 903410 files.
# Processed 903420 files.
# Processed 903430 files.
# Processed 903440 files.
# Processed 903450 files.
# Processed 903460 files.
# Processed 903470 files.
# Processed 903480 files.
# Processed 903490 files.
# Processed 903500 files.
# Processed 903510 files.
# Processed 903520 files.
# Processed 903530 files.
# Processed 903540 files.
# Processed 903550 files.
# Processed 903560 files.
# Processed 903570 files.
# Processed 903580 files.
# Processed 903590 files.
# Processed 903600 files.
# Processed 903610 files.
# Processed 903620 files.
# Processed 903630 files.
# Processed 903640 files.
# Processed 903650 files.
# Processed 903660 files.
# Processed 903670 files.
# Processed 903680 files.
# Processed 903690 files.
# Processed 903700 files.
# Processed 903710 files.
# Processed 903720 files.
# Processed 903730 files.
# Processed 903740 files.
# Processed 903750 files.
# Processed 903760 files.
# Processed 903770 files.
# Processed 903780 files.
# Processed 903790 files.
# Processed 903800 files.
# Processed 903810 files.
# Processed 903820 files.
# Processed 903830 files.
# Processed 903840 files.
# Processed 903850 files.
# Processed 903860 files.
# Processed 903870 files.
# Processed 903880 files.
# Processed 903890 files.
# Processed 903900 files.
# Processed 903910 files.
# Processed 903920 files.
# Processed 903930 files.
# Processed 903940 files.
# Processed 903950 files.
# Processed 903960 files.
# Processed 903970 files.
# Processed 903980 files.
# Processed 903990 files.
# Processed 904000 files.
# Processed 904010 files.
# Processed 904020 files.
# Processed 904030 files.
# Processed 904040 files.
# Processed 904050 files.
# Processed 904060 files.
# Processed 904070 files.
# Processed 904080 files.
# Processed 904090 files.
# Processed 904100 files.
# Processed 904110 files.
# Processed 904120 files.
# Processed 904130 files.
# Processed 904140 files.
# Processed 904150 files.
# Processed 904160 files.
# Processed 904170 files.
# Processed 904180 files.
# Processed 904190 files.
# Processed 904200 files.
# Processed 904210 files.
# Processed 904220 files.
# Processed 904230 files.
# Processed 904240 files.
# Processed 904250 files.
# Processed 904260 files.

# %% [markdown]
#  Now, you should be able to create a genre sample with the same code as for other macocu corpora.

# %% [markdown]
# # Old code

# %%
# Extract texts

texts = []
text_ids = []

for line in open("datasets/MaCoCu-sq.tsv"):
    did,text=line.strip().split('\t')
    texts.append(text)
    text_ids.append(did)

print(len(texts), len(text_ids))
# Out:
# 513904 513904

# %%
# Create a df out of the extacted texts and ids
text_file = pd.DataFrame({"text_id":text_ids,"text":texts})

text_file.head(3)
# Out:
#        text_id                                               text
# 0  macocu.mt.1  Bil-Filmat: Diversi Żgħażagħ Barranin Qaqoċċa ...
# 1  macocu.mt.2  Itlob biex jiġi jżurek Xhud taʼ Ġeħova biex ti...
# 2  macocu.mt.5  tal-Għaqda Dilettanti Knisja ta' Lapsi, San Ġi...

# %%
# Merge the dfs

df = text_file.merge(genre_file, on="text_id")

df.head()
# Out:
#        text_id                                               text  \
# 0  macocu.mt.1  Bil-Filmat: Diversi Żgħażagħ Barranin Qaqoċċa ...
# 1  macocu.mt.2  Itlob biex jiġi jżurek Xhud taʼ Ġeħova biex ti...
# 2  macocu.mt.5  tal-Għaqda Dilettanti Knisja ta' Lapsi, San Ġi...
# 3  macocu.mt.7  Intant, ħu pjaċir. U jekk tkun trid tgħaddilna...
# 4  macocu.mt.9  Qegħdin hawn biex ngħinuk. <p>Il-Family Planni...
#
#                      genre
# 0                    Other
# 1            Prose/Lyrical
# 2  Information/Explanation
# 3            Prose/Lyrical
# 4                      Mix

# %%
df.shape
# Out:
# (513904, 3)

# %%
# Add text length information
df["text_length"] = df.text.apply(lambda x:len(x.split()))

df.head()
# Out:
#        text_id                                               text  \
# 0  macocu.mt.1  Bil-Filmat: Diversi Żgħażagħ Barranin Qaqoċċa ...
# 1  macocu.mt.2  Itlob biex jiġi jżurek Xhud taʼ Ġeħova biex ti...
# 2  macocu.mt.5  tal-Għaqda Dilettanti Knisja ta' Lapsi, San Ġi...
# 3  macocu.mt.7  Intant, ħu pjaċir. U jekk tkun trid tgħaddilna...
# 4  macocu.mt.9  Qegħdin hawn biex ngħinuk. <p>Il-Family Planni...
#
#                      genre  text_length
# 0                    Other          102
# 1            Prose/Lyrical          124
# 2  Information/Explanation          297
# 3            Prose/Lyrical          413
# 4                      Mix          367

# %%
df.describe(include="all")
# Out:
#             text_id                                               text  \
# count        513904                                             513904
# unique       513904                                             513904
# top     macocu.mt.1  Bil-Filmat: Diversi Żgħażagħ Barranin Qaqoċċa ...
# freq              1                                                  1
# mean            NaN                                                NaN
# std             NaN                                                NaN
# min             NaN                                                NaN
# 25%             NaN                                                NaN
# 50%             NaN                                                NaN
# 75%             NaN                                                NaN
# max             NaN                                                NaN
#
#                           genre    text_length
# count                    513904  513904.000000
# unique                       10            NaN
# top     Information/Explanation            NaN
# freq                     210002            NaN
# mean                        NaN     423.462176
# std                         NaN     126.537873
# min                         NaN      76.000000
# 25%                         NaN     366.000000
# 50%                         NaN     512.000000
# 75%                         NaN     512.000000
# max                         NaN     512.000000

# %%
print(df.genre.value_counts(normalize="True").to_markdown())
# Out:
# | genre                   |   proportion |
# |:------------------------|-------------:|
# | Information/Explanation |  0.408641    |
# | Mix                     |  0.242082    |
# | Forum                   |  0.101274    |
# | Opinion/Argumentation   |  0.0943892   |
# | Other                   |  0.0712001   |
# | Prose/Lyrical           |  0.0700773   |
# | Instruction             |  0.00454365  |
# | Promotion               |  0.00443857  |
# | News                    |  0.00332747  |
# | Legal                   |  2.72424e-05 |

# %%
print(df.genre.value_counts().to_markdown())
# Out:
# | genre                   |   count |
# |:------------------------|--------:|
# | Information/Explanation |  210002 |
# | Mix                     |  124407 |
# | Forum                   |   52045 |
# | Opinion/Argumentation   |   48507 |
# | Other                   |   36590 |
# | Prose/Lyrical           |   36013 |
# | Instruction             |    2335 |
# | Promotion               |    2281 |
# | News                    |    1710 |
# | Legal                   |      14 |

# %%
# Save the file as it is
df.to_csv("/cache/tajak/macocu-mt/MaCoCu-sq-texts-with-genres.tsv", sep="\t")

# %%
# Compare the file created with original code and the file created with the extended improved code
old_file = pd.read_csv("/cache/tajak/macocu-mt/MaCoCu-mt-texts-with-genres.tsv", sep="\t", index_col = 0)

display(old_file)

new_file = pd.read_json("/cache/tajak/macocu-mt/MaCoCu-mt-2.0.tsv-genre-annotated.jsonl", orient="records", lines=True)

display(new_file)

print(old_file.shape, new_file.shape)
# Out:
#                  text_id                                               text  \
# 0            macocu.mt.1  Bil-Filmat: Diversi Żgħażagħ Barranin Qaqoċċa ...
# 1            macocu.mt.2  Itlob biex jiġi jżurek Xhud taʼ Ġeħova biex ti...
# 2            macocu.mt.5  tal-Għaqda Dilettanti Knisja ta' Lapsi, San Ġi...
# 3            macocu.mt.7  Intant, ħu pjaċir. U jekk tkun trid tgħaddilna...
# 4            macocu.mt.9  Qegħdin hawn biex ngħinuk. <p>Il-Family Planni...
# ...                  ...                                                ...
# 513899  macocu.mt.537330  Events info <p>Aħbarijiet <p>Għaliex xogħol st...
# 513900  macocu.mt.537331  Il-manifatturi, l-importaturi u l-utenti downs...
# 513901  macocu.mt.537332  Fażijiet Ħarsa ġenerali Proċess ta' valutazzjo...
# 513902  macocu.mt.537334  Id-deċiżjonijiet kollha ta' awtorizzazzjoni għ...
# 513903  macocu.mt.537336  Events info <p>Aħbarijiet <p>Ħila li kulħadd i...
#
#                           genre  text_length
# 0                         Other          102
# 1                 Prose/Lyrical          124
# 2       Information/Explanation          297
# 3                 Prose/Lyrical          413
# 4                           Mix          367
# ...                         ...          ...
# 513899                      Mix          454
# 513900  Information/Explanation          283
# 513901  Information/Explanation          153
# 513902  Information/Explanation          139
# 513903                      Mix          416
#
# [513904 rows x 4 columns]
#              document_id                                               text  \
# 0            macocu.mt.1  Bil-Filmat: Diversi Żgħażagħ Barranin Qaqoċċa ...
# 1            macocu.mt.2  Itlob biex jiġi jżurek Xhud taʼ Ġeħova biex ti...
# 2            macocu.mt.5  tal-Għaqda Dilettanti Knisja ta' Lapsi, San Ġi...
# 3            macocu.mt.7  Intant, ħu pjaċir. U jekk tkun trid tgħaddilna...
# 4            macocu.mt.9  Qegħdin hawn biex ngħinuk. <p>Il-Family Planni...
# ...                  ...                                                ...
# 513899  macocu.mt.537330  Events info <p>Aħbarijiet <p>Għaliex xogħol st...
# 513900  macocu.mt.537331  Il-manifatturi, l-importaturi u l-utenti downs...
# 513901  macocu.mt.537332  Fażijiet Ħarsa ġenerali Proċess ta' valutazzjo...
# 513902  macocu.mt.537334  Id-deċiżjonijiet kollha ta' awtorizzazzjoni għ...
# 513903  macocu.mt.537336  Events info <p>Aħbarijiet <p>Ħila li kulħadd i...
#
#                           genre  \
# 0                         Other
# 1                 Prose/Lyrical
# 2       Information/Explanation
# 3                 Prose/Lyrical
# 4                           Mix
# ...                         ...
# 513899                      Mix
# 513900  Information/Explanation
# 513901  Information/Explanation
# 513902  Information/Explanation
# 513903                      Mix
#
#                                                     logit
# 0       [6.211301326751709, -1.123962044715881, -2.108...
# 1       [1.873501896858215, -0.670612275600433, -1.697...
# 2       [-0.45298385620117104, 8.026633262634277, -1.0...
# 3       [0.431536048650741, -1.36893618106842, -1.2726...
# 4       [3.972864389419555, -0.131693825125694, -2.675...
# ...                                                   ...
# 513899  [2.540858268737793, 4.555283546447754, -1.7210...
# 513900  [-0.7114518880844111, 8.28370189666748, -0.954...
# 513901  [-0.7427962422370911, 8.293700218200684, -0.53...
# 513902  [0.496592551469802, 7.515917778015137, -1.6420...
# 513903  [3.997206926345825, -1.461642742156982, -2.435...
#
# [513904 rows x 4 columns]
# (513904, 4) (513904, 4)

# %%
display(new_file.genre.value_counts())

display(old_file.genre.value_counts())
# Out:
# genre
# Information/Explanation    210002
# Mix                        124407
# Forum                       52045
# Opinion/Argumentation       48507
# Other                       36590
# Prose/Lyrical               36013
# Instruction                  2335
# Promotion                    2281
# News                         1710
# Legal                          14
# Name: count, dtype: int64
# genre
# Information/Explanation    210002
# Mix                        124407
# Forum                       52045
# Opinion/Argumentation       48507
# Other                       36590
# Prose/Lyrical               36013
# Instruction                  2335
# Promotion                    2281
# News                         1710
# Legal                          14
# Name: count, dtype: int64

# %%
# Unzip the ZIP folder with the files
import zipfile

folder = "datasets/MaCoCu-sq-1.0.xml.zip"

with zipfile.ZipFile(folder, 'r') as zip_ref:
    zip_ref.extractall()

# %%
def merge_prevert_with_sample(sample_path, prevert_path):
    from prevert import dataset

    # Open the file that has the texts with genres sample
    sample = pd.read_csv(sample_path, sep="\t", index_col = 0)

    # Extract the list of all text ids
    text_ids = sample.text_id.to_list()

    prevert_texts = {}
    domains = {}

    # Open the dataset with the prevert parser 
    dset = dataset(prevert_path)

    # loop through the documents in MaCoCu prevert corpus and add
    # the document to the sample list if its id is in the genre sample
    for doc in tqdm(dset): # iterating through documents of a dataset
        current_text = ""
        current_text_id = doc.meta["id"]
        current_domain = doc.meta["domain"]
        if any(text_id == current_text_id for text_id in text_ids):
            for par in doc: # iterating through paragraphs of a document
                current_text += str(par)
                current_text += "\n"
            prevert_texts[current_text_id] = current_text
            domains[current_text_id] = current_domain
        else:
            continue

    print("Processing finished.")

    # Then append the new information to a df
    prevert_df = pd.DataFrame(list(zip(domains.keys(), domains.values(), prevert_texts.values())), columns=["text_id", 'domain', 'text'])

    # Merge the new dataframe to the sample dataframe
    final_df = sample.merge(prevert_df, on="text_id")

    # Remove unnecessary columns
    final_df = final_df.drop(columns=["Unnamed: 0", "text_x"])

    # Rename the text_y column
    final_df.rename(columns={"text_y":"text"}, inplace=True)

    # Save the file
    final_df.to_csv("{}-extracted-text-from-prevert.csv".format(sample_path))

    print("File created and saved as {}-extracted-text-from-prevert.csv".format(sample_path))

    return final_df

# %%
merge_prevert_with_sample("datasets/MaCoCu-sq-texts-with-genres.tsv-genre-sample.txt", "datasets/MaCoCu-sq-1.0.xml")

# %%
def prevert_enriched_sample_to_json(file_path, lang):
	""" Convert genre sample, enriched with the texts from the prevert corpus that have paragraph structure to a JSON file and translate them. This function is meant for corpora which were not extracted from VERT files, e.g. SQ corpus.

		Args:
		- file_path: path to the genre sample, created with the function merge_prevert_with_sample()
		- lang: sq"""

	sample_df = pd.read_csv(file_path, index_col = 0)

	# Apply Google Translate and machine translate the data
	import googletrans
	from googletrans import Translator

	# Define the translation model
	translator = Translator()

	# Create the final list
	translation_GT = []

	sentence_list = sample_df["text"].to_list()

	print("Starting translation.")

	# Loop through the list of original sentences,
	# translate each and append the translation to the final list
	for i in sentence_list:
		# Translate the sentence from source language, e.g. Slovene (src = "sl") to English (dest = "en")
			current_translation = translator.translate(i, src = lang, dest='en')
		# Append the translated sentence to the final list
			translation_GT.append(current_translation.text)

	print("Translation finished.")

	# Append translations to the sample

	sample_df["translation"] = translation_GT

	# Save to JSON lines
	sample_df.to_json("datasets/CLASSLA-web.{}.1.0.-translated-genre-sample.jsonl".format(lang), orient="records", lines=True)

	print("Final file saved as datasets/CLASSLA-web.{}.1.0.-translated-genre-sample.jsonl".format(lang))

	# Create also a version for the annotation tool, only with translation and labels
	ann_df = sample_df[["translation","genre"]]

	# For annotation, each label should be in a list
	ann_df["genre"] = ann_df["genre"].apply(lambda x:[x])

	# Rename df
	ann_df.columns = ["text", "label"]

	# Add metadata
	text_ids = sample_df["text_id"].to_list()
	domains = sample_df["domain"].to_list()

	metadata_list = []

	for i in list(zip(text_ids,domains)):
		metadata = {"text_id": i[0], "domain": i[1]}
		metadata_list.append(metadata)

	ann_df["metadata"] = metadata_list

	# Save to JSON lines
	ann_df.to_json("datasets/CLASSLA-web.{}.1.0.-translated-genre-sample-for-annotation.jsonl".format(lang), orient="records", lines=True)

	print("File for annotation saved as datasets/CLASSLA-web.{}.1.0.-translated-genre-sample-for-annotation.jsonl".format(lang))

	return sample_df

# %%
prevert_enriched_sample_to_json("datasets/MaCoCu-sq-texts-with-genres.tsv-genre-sample.txt-extracted-text-from-prevert.csv", "sq")
# Out:
# Starting translation.
# Translation finished.
# Final file saved as datasets/CLASSLA-web.sq.1.0.-translated-genre-sample.jsonl
# File for annotation saved as datasets/CLASSLA-web.sq.1.0.-translated-genre-sample-for-annotation.jsonl
# /tmp/ipykernel_1144159/1328090974.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ann_df["genre"] = ann_df["genre"].apply(lambda x:[x])
# /tmp/ipykernel_1144159/1328090974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ann_df["metadata"] = metadata_list
#               text_id                    genre  text_length  \
# 0   macocu.sq.1061396    Opinion/Argumentation          341
# 1   macocu.sq.1408163                Promotion          231
# 2    macocu.sq.183383                    Legal          140
# 3   macocu.sq.1191613                     News          115
# 4   macocu.sq.1104611                    Other          342
# ..                ...                      ...          ...
# 85   macocu.sq.915191                    Forum          235
# 86  macocu.sq.1060790  Information/Explanation          121
# 87   macocu.sq.581026    Opinion/Argumentation          437
# 88  macocu.sq.1118037                    Other          223
# 89  macocu.sq.1477999    Opinion/Argumentation          137
#
#                  domain                                               text  \
# 0       fjalaejetes.org  Blog\n\n“Unë të kam dashur me një dashuri të p...
# 1    zemrashqiptare.net  Fronti Bashkimit Kombëtar Shqiptar (FBKSH), or...
# 2             eukos.org  Liria nga keqtrajtimi\n\nKonventa e të Drejtav...
# 3      sportekspres.com  Një milimetër larg golit, “VAR” bëhet makth pë...
# 4       burimijetes.com  Ç’MENDONI JU?\n\nPyetje: Nena ime ka pare ende...
# ..                  ...                                                ...
# 85        intervista.al  Gazeta Intervista\n\nGazeta Intervista\n\nPas ...
# 86      radioiliria.net  Aleksandra Stan dhe superhiti i saj “Mr.Saxobe...
# 87         novamedia.al  Përfundon operacioni i larjes se halesë se Edv...
# 88      burimijetes.com  A LEJOHET TË THEM “EL HAMDU LILAH” KUR TESHTIJ...
# 89  sq.yourliterary.com  Ne moshen 7-vjecare kam qene ne klase te pare,...
#
#                                           translation
# 0   Blog\n\n"I loved you with eternal love."Jer 31...
# 1   The Albanian National Union Front (FBKSH), the...
# 2   Freedom from mistreatment\n\nStudent Rights Co...
# 3   A millimeter away from goal, "Var" becomes nig...
# 4   What do you think?\n\nQuestion: My mother has ...
# ..                                                ...
# 85  Interview newspapers\n\nInterview newspapers\n...
# 86  Alexandra Stan and her superhiti "Mr.Axobeat"\...
# 87  The operation of Edvin Czech's dump mask is co...
# 88  Is it permissible to say "Al Hamdu lilah" when...
# 89  At the age of 7 I was in the first grade at th...
#
# [90 rows x 6 columns]

# %%
# Open the annotated part

annotated = pd.read_json("datasets/CLASSLA-sq-samo-oznaceni-primeri.jsonl", lines=True)
annotated.head(2)
# Out:
#    id                                               text  \
# 0   1  Blog\n\n"I loved you with eternal love."Jer 31...
# 1   2  The Albanian National Union Front (FBKSH), the...
#
#                                             metadata                    label  \
# 0  {'text_id': 'macocu.sq.1061396', 'domain': 'fj...  [Opinion/Argumentation]
# 1  {'text_id': 'macocu.sq.1408163', 'domain': 'ze...                  [Other]
#
#   Comments
# 0       []
# 1       []

# %%
annotated.tail()
# Out:
#     id                                               text  \
# 49  50  Altin Toska, CV\n\nThis is the vital curriculu...
# 50  51  Dermocosmetics\n\nLA ROCHE POSAY - TOLERIAN CA...
# 51  52  Does men's sleep worse with full moon?The stud...
# 52  53  Dear reader!\n\nTitle: Dear Reader!14.09.10 6:...
# 53  54  For example, it is preparing to take responsib...
#
#                                              metadata  \
# 49  {'text_id': 'macocu.sq.1616592', 'domain': 'pu...
# 50  {'text_id': 'macocu.sq.1486735', 'domain': 'fi...
# 51  {'text_id': 'macocu.sq.797062', 'domain': 'val...
# 52  {'text_id': 'macocu.sq.1576314', 'domain': 'yo...
# 53  {'text_id': 'macocu.sq.463621', 'domain': 'rre...
#
#                         label Comments
# 49  [Information/Explanation]       []
# 50                [Promotion]       []
# 51  [Information/Explanation]       []
# 52  [Information/Explanation]       []
# 53    [Opinion/Argumentation]       []

# %%
annotated.label.value_counts()
# Out:
# label
# [Forum]                      8
# [Information/Explanation]    8
# [Prose/Lyrical]              7
# [Instruction]                7
# [Opinion/Argumentation]      6
# [Legal]                      5
# [Promotion]                  5
# [News]                       4
# [Other]                      2
# [Incomprehensible]           1
# [Multiple texts]             1
# Name: count, dtype: int64

# %%
# Open the entire genre sample for annotation
sample = pd.read_json("datasets/CLASSLA-web.sq.1.0.-translated-genre-sample-for-annotation.jsonl", lines= True)

sample.head(2)
# Out:
#                                                 text                    label  \
# 0  Blog\n\n"I loved you with eternal love."Jer 31...  [Opinion/Argumentation]
# 1  The Albanian National Union Front (FBKSH), the...              [Promotion]
#
#                                             metadata
# 0  {'text_id': 'macocu.sq.1061396', 'domain': 'fj...
# 1  {'text_id': 'macocu.sq.1408163', 'domain': 'ze...

# %%
sample[52:55]
# Out:
#                                                  text  \
# 52  Dear reader!\n\nTitle: Dear Reader!14.09.10 6:...
# 53  For example, it is preparing to take responsib...
# 54  Edi Rama's star, here's what symbolizes\n\nEdi...
#
#                       label                                           metadata
# 52                  [Other]  {'text_id': 'macocu.sq.1576314', 'domain': 'yo...
# 53  [Opinion/Argumentation]  {'text_id': 'macocu.sq.463621', 'domain': 'rre...
# 54  [Opinion/Argumentation]  {'text_id': 'macocu.sq.372579', 'domain': 'jav...

# %%
unanno = sample[54:]
unanno.head()
# Out:
#                                                  text  \
# 54  Edi Rama's star, here's what symbolizes\n\nEdi...
# 55  If you are always tired, you can actually suff...
# 56  Enion Cala\n\nProduction, sale, import -export...
# 57  The secret falls!Now transparency on Albanians...
# 58  Dermedic Sunbrella Sun Protection Spf 50+\n\nP...
#
#                         label  \
# 54    [Opinion/Argumentation]
# 55              [Instruction]
# 56  [Information/Explanation]
# 57                     [News]
# 58                [Promotion]
#
#                                              metadata
# 54  {'text_id': 'macocu.sq.372579', 'domain': 'jav...
# 55  {'text_id': 'macocu.sq.1144450', 'domain': 'ar...
# 56  {'text_id': 'macocu.sq.1325438', 'domain': 'op...
# 57  {'text_id': 'macocu.sq.959055', 'domain': 'shq...
# 58  {'text_id': 'macocu.sq.296193', 'domain': 'far...

# %%
# Save the unannotated part
unanno.to_json("datasets/CLASSLA-sq-remaining-part-to-be-annotated.jsonl", orient="records", lines=True)

# %%
# Open samples

sample_paths = {"hr":"datasets/CLASSLA-web.hr.1.0.vert.gz-sample.txt-genre-sample.txt", "mk":"datasets/CLASSLA-web.mk.1.0.vert.gz-sample.txt-genre-sample.txt", "sl":"datasets/CLASSLA-web.sl.1.0.vert.gz-sample.txt-genre-sample.txt", "sq": "datasets/MaCoCu-sq-texts-with-genres.tsv-genre-sample.txt"}

# %%
def genre_sample_to_json(sample_paths, lang):
	""" Convert genre sample in TXT to JSON and add translations and paragraph structure.
	
		Args:
		- sample_paths: path to a file, created with the function extract_genre_sample
		- lang: hr, mk, sl"""
	
	sample_df = pd.read_csv(sample_paths[lang], sep="\t", index_col = 0)

	# Change <p> signs to actual new lines
	sample_df["text"] = sample_df["text"].str.replace("<p>", "\n\n")


	# Apply Google Translate and machine translate the data
	import googletrans
	from googletrans import Translator

	# Define the translation model
	translator = Translator()

	# Create the final list
	translation_GT = []

	sentence_list = sample_df["text"].to_list()

	print("Starting translation.")

	# Loop through the list of original sentences,
	# translate each and append the translation to the final list
	for i in sentence_list:
		# Translate the sentence from Slovene (src = "sl") to English (dest = "en")
			current_translation = translator.translate(i, src = lang, dest='en')
		# Append the translated sentence to the final list
			translation_GT.append(current_translation.text)

	print("Translation finished.")

	# Append translations to the sample

	sample_df["translation"] = translation_GT

	# Save to JSON lines
	sample_df.to_json("datasets/CLASSLA-web.{}.1.0.-translated-genre-sample.jsonl".format(lang), orient="records", lines=True)

	print("Final file saved as datasets/CLASSLA-web.{}.1.0.-translated-genre-sample.jsonl".format(lang))

	# Create also a version for the annotation tool, only with translation and labels
	ann_df = sample_df[["translation","genre"]]

	# For annotation, each label should be in a list
	ann_df["genre"] = ann_df["genre"].apply(lambda x:[x])

	# Rename df
	ann_df.columns = ["text", "label"]

	# Add metadata
	text_ids = sample_df["text_id"].to_list()
	domains = sample_df["domain"].to_list()

	metadata_list = []

	for i in list(zip(text_ids,domains)):
		metadata = {"text_id": i[0], "domain": i[1]}
		metadata_list.append(metadata)

	ann_df["metadata"] = metadata_list

	# Save to JSON lines
	ann_df.to_json("datasets/CLASSLA-web.{}.1.0.-translated-genre-sample-for-annotation.jsonl".format(lang), orient="records", lines=True)

	print("File for annotation saved as datasets/CLASSLA-web.{}.1.0.-translated-genre-sample-for-annotation.jsonl".format(lang))

	return sample_df

# %%
sample_hr = genre_sample_to_json(sample_paths, "mk")

sample_hr.head()
# Out:
# Starting translation.
# Translation finished.
# Final file saved as datasets/CLASSLA-web.mk.1.0.-translated-genre-sample.jsonl
# File for annotation saved as datasets/CLASSLA-web.mk.1.0.-translated-genre-sample-for-annotation.jsonl
# /tmp/ipykernel_3636988/3337467837.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ann_df["genre"] = ann_df["genre"].apply(lambda x:[x])
# /tmp/ipykernel_3636988/3337467837.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ann_df["metadata"] = metadata_list
#                       text_id  \
# 15197    CLASSLA-web.mk.18600
# 46057   CLASSLA-web.mk.138126
# 38999   CLASSLA-web.mk.921342
# 48491   CLASSLA-web.mk.384653
# 99412  CLASSLA-web.mk.1050389
#
#                                                      url            domain  \
# 15197                          https://radar.mk/?p=29847          radar.mk
# 46057                  https://emiter.com.mk/napis/10922     emiter.com.mk
# 38999  http://www.interesno.mk/nauka/38-nauka/50238-k...      interesno.mk
# 48491  https://www.mn.mk/pesni-za-makedonija/6075-Dob...             mn.mk
# 99412  http://forum.carclub.mk/index.php/topic,102.ms...  forum.carclub.mk
#
#                          genre  \
# 15197  Information/Explanation
# 46057  Information/Explanation
# 38999              Instruction
# 48491            Prose/Lyrical
# 99412                    Forum
#
#                                                     text  text_length  \
# 15197  Топењето на мразот е посебен феномен од 21-от ...          269
# 46057  Широката распространетост на РЕЛ-заварувањето ...          204
# 38999  Кои хороскопски знаци ќе ги погоди Розевата По...          195
# 48491  Валентина Ѓоргиевска Парго Добриот човек го им...          373
# 99412  Провери си тука http://www.autobulbsdirect.co....          440
#
#                                              translation
# 15197  Melting ice is a special 21st century phenomen...
# 46057  The widespread distribution of the relief and ...
# 38999  What zodiac signs would hit the pink full moon...
# 48491  Valentina Gjorgievska Pargo The good man has s...
# 99412  Check out here http://www.autobulbsdirect.co.u...
